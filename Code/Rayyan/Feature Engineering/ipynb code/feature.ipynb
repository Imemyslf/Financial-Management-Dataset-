# %%
import pandas as pd
import numpy as np 
import os

# %%
quarter_file = r"C:\Users\sharm\OneDrive\Desktop\Kishan\Contractzy\WebScrapping\Tutorial\Financial_Data\MoneyControl\Companies\IT Services & Consulting\3i Infotech Ltd\Pruned_Excel\Pruned_Quarterly-resul_combined.xlsx"
qua_df = pd.read_excel(quarter_file)
qua_df.head(5)
# Out:
#    Quarter  Net Sales/Income from operations  Total Income From Operations  \
# 0  Sep '13                             78.26                         78.26
# 1  Dec '13                             90.95                         90.95
# 2  Mar '14                             79.08                         79.08
# 3  Jun '14                             93.17                         93.17
# 4  Sep '14                            108.29                        108.29
#
#    Employees Cost  depreciat  Other Expenses  \
# 0           38.63      55.44           27.47
# 1           43.95      67.07           30.53
# 2           41.18      57.31           27.76
# 3           43.90      58.04           41.54
# 4           42.54      52.49           61.74
#
#    P/L Before Other Inc. , Int., Excpt. Items & Tax  Other Income  \
# 0                                            -43.28         21.86
# 1                                            -50.60         -1.12
# ...

# %%
qua_duplicates = qua_df[1:].T.duplicated(keep=False)

# %%
qua_duplicate_columns = qua_df.columns[qua_duplicates]
qua_duplicate_columns.tolist()
# Out:
# ['Net Sales/Income from operations', 'Total Income From Operations']

# %%
qua_df = qua_df.drop(columns=qua_duplicate_columns[0])
qua_df.head(3)
# Out:
#    Quarter  Total Income From Operations  Employees Cost  depreciat  \
# 0  Sep '13                         78.26           38.63      55.44
# 1  Dec '13                         90.95           43.95      67.07
# 2  Mar '14                         79.08           41.18      57.31
#
#    Other Expenses  P/L Before Other Inc. , Int., Excpt. Items & Tax  \
# 0           27.47                                            -43.28
# 1           30.53                                            -50.60
# 2           27.76                                            -47.17
#
#    Other Income  P/L Before Int., Excpt. Items & Tax  Interest  \
# 0         21.86                               -21.42     74.56
# 1         -1.12                               -51.72     87.49
# 2         10.78                               -36.39     64.37
#
#    P/L Before Exceptional Items & Tax  Exceptional Items  P/L Before Tax  \
# 0                              -95.98             -47.90          -95.98
# ...
