# %%
import os
import pandas as pd

# Define the base directory containing all company folders
input_file = r"C:\Users\rayya\OneDrive\Desktop\Programs\Financial-Management-Dataset-\Financial_Data\MoneyControl\Companies\IT Services & Consulting"
companies_list = os.listdir(input_file)

# Iterate over each company folder
for company in companies_list:
    file_path = os.path.join(input_file, company, "Pruned_Excel", "Final_Parameters", "Semi_Final")

    # Define file name
    excel_file = os.path.join(file_path, f"{company}_Semi_Final.xlsx")

    # Check if the file exists before processing
    if os.path.exists(excel_file):
        print(f"\nCompany: {company}")

        # Load all sheets from the Excel file
        dfs = pd.read_excel(excel_file, sheet_name=None)

        # Iterate through each sheet in the Excel file
        for sheet_name, df in dfs.items():
            print(f"\n  Sheet Name: {sheet_name}")

            # Count null values per column
            null_counts = df.isnull().sum()
            null_columns = null_counts[null_counts > 0]  # Only columns with nulls

            # Convert non-numeric columns to NaN (avoid counting 0s in text)
            df_numeric = df.apply(pd.to_numeric, errors='coerce')

            # Count occurrences of zero values per column
            zero_counts = (df_numeric == 0).sum()
            zero_columns = zero_counts[zero_counts > 0]  # Only columns with 0s

            # Display null values if any exist
            if not null_columns.empty:
                print("\n    Null Values:")
                for column, count in null_columns.items():
                    print(f"      {column}: {count}")

            # Display zero values if any exist
            if not zero_columns.empty:
                print("\n    Zero Values:")
                for column, count in zero_columns.items():
                    print(f"      {column}: {count}")
# Out:
# Company: 3i Infotech Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 5
#       Current tax: 13
#       Deferred tax: 9
#       Total tax expenses: 5
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 14
#       Tax: 32
#       Diluted eps: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Return on networth / equity (%): 1
#       Dividend payout ratio (np) (%): 13
#       Dividend payout ratio (cp) (%): 13
#       Earnings retention ratio (%): 13
#       Enterprise value (cr.): 1
#       Ev/ebitda (x): 1
#
# Company: Adroit Infotech Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 2
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used in investing activities: 5
#       Net cash used from financing activities: 8
#       Foreign exchange gains / losses: 20
#       Net inc/dec in cash and cash equivalents: 4
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 1
#       Revenue from operations [net]: 1
#       Total operating revenues: 1
#       Other income: 5
#       Operating and direct expenses: 12
#       Employee benefit expenses: 2
#       Finance costs: 7
#       Current tax: 15
#       Deferred tax: 9
#       Total tax expenses: 6
#       Profit/loss after tax and before extraordinary items: 2
#       Profit/loss from continuing operations: 1
#       Profit/loss for the period: 1
#       Basic eps (rs.): 2
#       Diluted eps (rs.): 2
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 2
#       Total income from operations: 1
#       Employees cost: 2
#       depreciat: 4
#       Other income: 18
#       Interest: 15
#       Exceptional items: 41
#       Tax: 28
#       Basic eps: 3
#       Diluted eps: 3
#       Basic eps.: 3
#       Diluted eps.: 3
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 1
#       Pbt/share (rs.): 1
#       Net profit/share (rs.): 2
#       Pbdit margin (%): 1
#       Pbit margin (%): 1
#       Pbt margin (%): 1
#       Net profit margin (%): 1
#       Total debt/equity (x): 9
#       Dividend payout ratio (np) (%): 19
#       Dividend payout ratio (cp) (%): 19
#       Earnings retention ratio (%): 19
#
# Company: Affle India Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 8
#
#   Sheet Name: Profit_Loss
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 25
#       Basic eps: 1
#       Diluted eps: 1
#       Basic eps.: 2
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 8
#       Dividend payout ratio (np) (%): 10
#       Dividend payout ratio (cp) (%): 10
#       Earnings retention ratio (%): 10
#       Enterprise value (cr.): 5
#       Ev/ebitda (x): 5
#
# Company: AION-TECH SOLUTIONS Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 1
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 6
#       Current tax: 4
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 7
#       Exceptional items: 44
#       Tax: 7
#       Basic eps: 1
#       Diluted eps: 2
#       Basic eps.: 1
#       Diluted eps.: 2
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 2
#       Dividend payout ratio (np) (%): 19
#       Dividend payout ratio (cp) (%): 19
#       Earnings retention ratio (%): 10
#
# Company: Allied Digital Services Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1
#       Net cashflow from operating activities: 1
#       Net cash used in investing activities: 1
#       Net cash used from financing activities: 1
#       Foreign exchange gains / losses: 20
#       Net inc/dec in cash and cash equivalents: 1
#       Cash and cash equivalents begin of year: 1
#       Cash and cash equivalents end of year: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 7
#       Current tax: 1
#       Deferred tax: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 43
#       Tax: 7
#       Basic eps: 1
#       Diluted eps: 1
#       Basic eps.: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 12
#       Dividend payout ratio (cp) (%): 12
#       Earnings retention ratio (%): 6
#       Enterprise value (cr.): 3
#       Ev/ebitda (x): 3
#
# Company: Alphalogic Techsys Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 5
#       Net inc/dec in cash and cash equivalents: 4
#       Cash and cash equivalents begin of year: 1
#       Cash and cash equivalents end of year: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 2
#       Deferred tax: 3
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       depreciat: 7
#       Exceptional items: 10
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 5
#       Dividend payout ratio (cp) (%): 5
#       Earnings retention ratio (%): 5
#
# Company: ASM Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 11
#       Net inc/dec in cash and cash equivalents: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 8
#       Current tax: 2
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 44
#       Diluted eps: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 3
#       Dividend payout ratio (cp) (%): 3
#
# Company: Atishay Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 15
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 1
#       Current tax: 1
#       Deferred tax: 3
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 34
#       Tax: 1
#       Basic eps: 1
#       Diluted eps: 1
#       Basic eps.: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 1
#       Dividend payout ratio (np) (%): 10
#       Dividend payout ratio (cp) (%): 10
#       Earnings retention ratio (%): 7
#       Enterprise value (cr.): 5
#       Ev/ebitda (x): 5
#
# Company: Avance Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 2
#       Tangible assets: 9
#       Fixed assets: 9
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1
#       Net cashflow from operating activities: 1
#       Net cash used in investing activities: 1
#       Net cash used from financing activities: 6
#       Foreign exchange gains / losses: 15
#       Net inc/dec in cash and cash equivalents: 1
#       Cash and cash equivalents begin of year: 1
#       Cash and cash equivalents end of year: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 12
#       Employee benefit expenses: 1
#       Finance costs: 12
#       Depreciation and amortisation expenses: 9
#       Current tax: 8
#       Deferred tax: 10
#       Total tax expenses: 6
#       Basic eps (rs.): 4
#       Diluted eps (rs.): 4
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 6
#       Total income from operations: 4
#       Employees cost: 10
#       depreciat: 37
#       Other expenses: 5
#       P/l before other inc. , int., excpt. items & tax: 1
#       Other income: 31
#       P/l before int., excpt. items & tax: 1
#       Interest: 41
#       P/l before exceptional items & tax: 1
#       Exceptional items: 35
#       Tax: 40
#       Basic eps: 27
#       Diluted eps: 27
#       Basic eps.: 26
#       Diluted eps.: 26
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 1
#       Pbdit/share (rs.): 5
#       Pbit/share (rs.): 5
#       Pbt/share (rs.): 2
#       Net profit/share (rs.): 3
#       Total debt/equity (x): 8
#       Dividend payout ratio (np) (%): 15
#       Dividend payout ratio (cp) (%): 15
#       Earnings retention ratio (%): 13
#
# Company: Bartronics India Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 1
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1
#       Net cashflow from operating activities: 1
#       Net cash used in investing activities: 1
#       Net cash used from financing activities: 2
#       Foreign exchange gains / losses: 19
#       Net inc/dec in cash and cash equivalents: 2
#       Cash and cash equivalents begin of year: 2
#       Cash and cash equivalents end of year: 2
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 16
#       Finance costs: 1
#       Current tax: 12
#       Deferred tax: 2
#       Diluted eps (rs.): 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 4
#       Interest: 7
#       Exceptional items: 38
#       Tax: 1
#       Basic eps: 2
#       Diluted eps: 3
#       Basic eps.: 3
#       Diluted eps.: 3
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Return on networth / equity (%): 3
#       Total debt/equity (x): 1
#       Dividend payout ratio (np) (%): 17
#       Dividend payout ratio (cp) (%): 17
#       Earnings retention ratio (%): 12
#       Enterprise value (cr.): 2
#       Ev/ebitda (x): 2
#
# Company: Birlasoft Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 6
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 43
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 5
#
# Company: Cambridge Technology Enterprises Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1
#       Net cashflow from operating activities: 1
#       Net cash used in investing activities: 1
#       Net cash used from financing activities: 3
#       Foreign exchange gains / losses: 20
#       Net inc/dec in cash and cash equivalents: 1
#       Cash and cash equivalents begin of year: 1
#       Cash and cash equivalents end of year: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Other income: 1
#       Operating and direct expenses: 2
#       Employee benefit expenses: 1
#       Finance costs: 2
#       Other expenses: 1
#       Current tax: 9
#       Deferred tax: 5
#       Total tax expenses: 3
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 12
#       Exceptional items: 42
#       Tax: 2
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 6
#       Dividend payout ratio (np) (%): 19
#       Dividend payout ratio (cp) (%): 19
#       Earnings retention ratio (%): 13
#       Enterprise value (cr.): 2
#       Ev/ebitda (x): 2
#
# Company: CG-Vak Software and Exports Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20
#       Net inc/dec in cash and cash equivalents: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14
#       Employee benefit expenses: 2
#       Finance costs: 1
#       Current tax: 4
#       Deferred tax: 3
#       Total tax expenses: 1
#       Profit/loss from continuing operations: 1
#       Profit/loss for the period: 1
#       Basic eps (rs.): 1
#       Diluted eps (rs.): 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 1
#       Interest: 17
#       Exceptional items: 45
#       Tax: 1
#       P/l after tax from ordinary activities: 1
#       Net profit/(loss) for the period: 1
#       Basic eps: 1
#       Diluted eps: 1
#       Basic eps.: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Net profit/share (rs.): 1
#       Total debt/equity (x): 5
#       Dividend payout ratio (np) (%): 8
#       Dividend payout ratio (cp) (%): 8
#       Earnings retention ratio (%): 4
#
# Company: COFORGE LIMITED Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14
#       Current tax: 1
#       Deferred tax: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 39
#       Diluted eps: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 5
#
# Company: Cranes Software International Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 1
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cashflow from operating activities: 1
#       Net cash used in investing activities: 2
#       Net cash used from financing activities: 2
#       Foreign exchange gains / losses: 18
#       Net inc/dec in cash and cash equivalents: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 2
#       Revenue from operations [net]: 2
#       Total operating revenues: 2
#       Other income: 1
#       Total revenue: 1
#       Operating and direct expenses: 6
#       Finance costs: 1
#       Current tax: 14
#       Deferred tax: 1
#       Total tax expenses: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 11
#       Total income from operations: 11
#       depreciat: 1
#       Other income: 10
#       Interest: 13
#       Exceptional items: 36
#       Tax: 7
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 2
#       Pbdit margin (%): 2
#       Pbit margin (%): 2
#       Pbt margin (%): 2
#       Net profit margin (%): 2
#       Return on networth / equity (%): 11
#       Total debt/equity (x): 8
#       Dividend payout ratio (np) (%): 15
#       Dividend payout ratio (cp) (%): 15
#       Earnings retention ratio (%): 15
#
# Company: Cressanda Solution Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 1
#       Total current liabilities: 1
#       Tangible assets: 8
#       Fixed assets: 8
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1
#       Net cash used in investing activities: 9
#       Net cash used from financing activities: 8
#       Foreign exchange gains / losses: 20
#       Net inc/dec in cash and cash equivalents: 3
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 8
#       Revenue from operations [net]: 8
#       Total operating revenues: 8
#       Other income: 4
#       Total revenue: 3
#       Operating and direct expenses: 13
#       Employee benefit expenses: 1
#       Finance costs: 14
#       Depreciation and amortisation expenses: 9
#       Profit/loss before exceptional, extraordinary items and tax: 1
#       Profit/loss before tax: 1
#       Current tax: 15
#       Deferred tax: 20
#       Total tax expenses: 11
#       Profit/loss after tax and before extraordinary items: 1
#       Profit/loss from continuing operations: 1
#       Profit/loss for the period: 1
#       Basic eps (rs.): 5
#       Diluted eps (rs.): 5
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 27
#       Total income from operations: 27
#       Employees cost: 11
#       depreciat: 39
#       Other expenses: 8
#       P/l before other inc. , int., excpt. items & tax: 2
#       Other income: 27
#       P/l before int., excpt. items & tax: 3
#       Interest: 43
#       P/l before exceptional items & tax: 3
#       Exceptional items: 39
#       P/l before tax: 3
#       Tax: 33
#       P/l after tax from ordinary activities: 3
#       Net profit/(loss) for the period: 3
#       Basic eps: 30
#       Diluted eps: 30
#       Basic eps.: 30
#       Diluted eps.: 30
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 9
#       Pbdit/share (rs.): 5
#       Pbit/share (rs.): 4
#       Pbt/share (rs.): 4
#       Net profit/share (rs.): 4
#       Pbdit margin (%): 8
#       Pbit margin (%): 8
#       Pbt margin (%): 8
#       Net profit margin (%): 8
#       Total debt/equity (x): 12
#       Dividend payout ratio (np) (%): 20
#       Dividend payout ratio (cp) (%): 20
#       Earnings retention ratio (%): 17
#
# Company: Cybertech Systems and Software Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used from financing activities: 1
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Finance costs: 4
#       Current tax: 2
#       Deferred tax: 4
#       Total tax expenses: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 1
#       Exceptional items: 44
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Pbit/share (rs.): 1
#       Pbt/share (rs.): 1
#       Total debt/equity (x): 8
#       Dividend payout ratio (np) (%): 2
#       Dividend payout ratio (cp) (%): 2
#       Earnings retention ratio (%): 1
#
# Company: Cyient Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 2
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 1
#       Exceptional items: 41
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 17
#       Dividend payout ratio (np) (%): 1
#       Dividend payout ratio (cp) (%): 1
#       Earnings retention ratio (%): 1
#
# Company: Danlaw Technologies India Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cashflow from operating activities: 1
#       Net cash used in investing activities: 1
#       Net cash used from financing activities: 8
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14
#       Finance costs: 5
#       Current tax: 9
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       P/l before other inc. , int., excpt. items & tax: 1
#       Interest: 19
#       Exceptional items: 45
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 13
#       Dividend payout ratio (np) (%): 20
#       Dividend payout ratio (cp) (%): 20
#       Earnings retention ratio (%): 14
#
# Company: Datamatics Global Services Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used from financing activities: 1
#       Foreign exchange gains / losses: 13
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 1
#       Finance costs: 3
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 38
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 7
#       Dividend payout ratio (np) (%): 1
#       Dividend payout ratio (cp) (%): 1
#       Earnings retention ratio (%): 1
#
# Company: Dev Information Technology Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 10
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 4
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 15
#       Diluted eps: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 1
#       Dividend payout ratio (cp) (%): 1
#       Earnings retention ratio (%): 1
#       Enterprise value (cr.): 3
#       Ev/ebitda (x): 3
#
# Company: Dynacons Systems and Solutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 3
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Other income: 2
#       Total tax expenses: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 16
#       Exceptional items: 45
#       P/l after tax from ordinary activities: 1
#       Net profit/(loss) for the period: 1
#       Basic eps: 1
#       Diluted eps: 1
#       Basic eps.: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 15
#       Dividend payout ratio (cp) (%): 15
#       Earnings retention ratio (%): 7
#
# Company: Elnet Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 20
#       Finance costs: 3
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 15
#       Exceptional items: 43
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 3
#       Dividend payout ratio (cp) (%): 3
#       Earnings retention ratio (%): 3
#
# Company: Equippp Social Impact Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used in investing activities: 4
#       Foreign exchange gains / losses: 16
#       Net inc/dec in cash and cash equivalents: 2
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 3
#       Revenue from operations [net]: 3
#       Total operating revenues: 3
#       Other income: 3
#       Total revenue: 2
#       Operating and direct expenses: 11
#       Finance costs: 2
#       Current tax: 11
#       Deferred tax: 13
#       Total tax expenses: 10
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 16
#       Total income from operations: 16
#       depreciat: 28
#       Other expenses: 1
#       Other income: 34
#       Interest: 12
#       Exceptional items: 43
#       Tax: 43
#       Basic eps: 4
#       Diluted eps: 5
#       Basic eps.: 4
#       Diluted eps.: 5
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 3
#       Pbit/share (rs.): 1
#       Pbdit margin (%): 3
#       Pbit margin (%): 3
#       Pbt margin (%): 3
#       Net profit margin (%): 3
#       Return on networth / equity (%): 7
#       Total debt/equity (x): 4
#       Dividend payout ratio (np) (%): 16
#       Dividend payout ratio (cp) (%): 16
#       Earnings retention ratio (%): 16
#       Enterprise value (cr.): 2
#       Ev/ebitda (x): 2
#
# Company: Expleo Solutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 3
#       Net cashflow from operating activities: 3
#       Net cash used in investing activities: 3
#       Net cash used from financing activities: 3
#       Foreign exchange gains / losses: 8
#       Net inc/dec in cash and cash equivalents: 3
#       Cash and cash equivalents begin of year: 3
#       Cash and cash equivalents end of year: 3
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 6
#       Finance costs: 3
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 10
#       Exceptional items: 44
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 16
#       Dividend payout ratio (np) (%): 5
#       Dividend payout ratio (cp) (%): 5
#       Earnings retention ratio (%): 5
#       Enterprise value (cr.): 5
#       Ev/ebitda (x): 5
#
# Company: FCS Software Solutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 11
#       Other expenses: 4
#       Deferred tax: 1
#       Basic eps (rs.): 1
#       Diluted eps (rs.): 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other expenses: 9
#       Interest: 3
#       Exceptional items: 32
#       Tax: 1
#       P/l after tax from ordinary activities: 2
#       Net profit/(loss) for the period: 2
#       Basic eps: 23
#       Diluted eps: 25
#       Basic eps.: 24
#       Diluted eps.: 26
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Pbit/share (rs.): 1
#       Pbt/share (rs.): 2
#       Net profit/share (rs.): 1
#       Total debt/equity (x): 4
#       Dividend payout ratio (np) (%): 16
#       Dividend payout ratio (cp) (%): 16
#       Earnings retention ratio (%): 15
#
# Company: Genesys International Corporation Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 5
#       Current tax: 5
#       Deferred tax: 5
#       Total tax expenses: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 43
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 2
#       Dividend payout ratio (np) (%): 7
#       Dividend payout ratio (cp) (%): 7
#       Earnings retention ratio (%): 6
#
# Company: Happiest Minds Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 5
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 15
#       Tax: 1
#       Diluted eps: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 2
#       Dividend payout ratio (cp) (%): 2
#       Earnings retention ratio (%): 2
#       Enterprise value (cr.): 1
#       Ev/ebitda (x): 1
#
# Company: HCL Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 3
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 6
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 45
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 10
#
# Company: Indian Infotech and Software Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 9
#       Total current liabilities: 2
#       Tangible assets: 7
#       Fixed assets: 4
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1
#       Net cashflow from operating activities: 1
#       Net cash used in investing activities: 6
#       Net cash used from financing activities: 3
#       Foreign exchange gains / losses: 20
#       Net inc/dec in cash and cash equivalents: 2
#       Cash and cash equivalents begin of year: 2
#       Cash and cash equivalents end of year: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 1
#       Revenue from operations [net]: 1
#       Total operating revenues: 1
#       Other income: 6
#       Operating and direct expenses: 15
#       Employee benefit expenses: 1
#       Finance costs: 13
#       Depreciation and amortisation expenses: 6
#       Profit/loss before exceptional, extraordinary items and tax: 1
#       Profit/loss before tax: 1
#       Current tax: 11
#       Deferred tax: 14
#       Total tax expenses: 6
#       Profit/loss after tax and before extraordinary items: 1
#       Profit/loss from continuing operations: 1
#       Profit/loss for the period: 1
#       Basic eps (rs.): 5
#       Diluted eps (rs.): 5
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Employees cost: 2
#       depreciat: 22
#       Other income: 42
#       Interest: 41
#       Exceptional items: 45
#       Tax: 24
#       Basic eps: 10
#       Diluted eps: 10
#       Basic eps.: 10
#       Diluted eps.: 10
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 2
#       Pbdit/share (rs.): 3
#       Pbit/share (rs.): 7
#       Pbt/share (rs.): 7
#       Net profit/share (rs.): 5
#       Pbdit margin (%): 1
#       Pbit margin (%): 1
#       Pbt margin (%): 1
#       Net profit margin (%): 1
#       Total debt/equity (x): 14
#       Dividend payout ratio (np) (%): 20
#       Dividend payout ratio (cp) (%): 20
#       Earnings retention ratio (%): 16
#
# Company: Infosys Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Finance costs: 15
#       Deferred tax: 2
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 22
#       Exceptional items: 44
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 20
#
# Company: Inspirisys Solutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1
#       Net cashflow from operating activities: 1
#       Net cash used in investing activities: 1
#       Net cash used from financing activities: 1
#       Foreign exchange gains / losses: 19
#       Net inc/dec in cash and cash equivalents: 1
#       Cash and cash equivalents begin of year: 1
#       Cash and cash equivalents end of year: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 19
#       Current tax: 2
#       Deferred tax: 8
#       Total tax expenses: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Employees cost: 4
#       Exceptional items: 42
#       Tax: 9
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Return on networth / equity (%): 2
#       Dividend payout ratio (np) (%): 12
#       Dividend payout ratio (cp) (%): 12
#       Earnings retention ratio (%): 12
#       Enterprise value (cr.): 2
#       Ev/ebitda (x): 2
#
# Company: Intellect Design Arena Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 2
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 8
#       Finance costs: 1
#       Current tax: 3
#       Deferred tax: 1
#       Total tax expenses: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 5
#       Exceptional items: 39
#       Tax: 13
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 4
#       Dividend payout ratio (np) (%): 8
#       Dividend payout ratio (cp) (%): 8
#       Earnings retention ratio (%): 8
#
# Company: IZMO Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 2
#       Current tax: 2
#       Deferred tax: 2
#       Total tax expenses: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 42
#       Tax: 28
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Pbt/share (rs.): 1
#       Total debt/equity (x): 3
#       Dividend payout ratio (np) (%): 18
#       Dividend payout ratio (cp) (%): 18
#       Earnings retention ratio (%): 9
#
# Company: Jeevan Scientific Technology Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 15
#       Net inc/dec in cash and cash equivalents: 3
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 3
#       Finance costs: 1
#       Current tax: 9
#       Deferred tax: 6
#       Total tax expenses: 6
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 3
#       Exceptional items: 43
#       Tax: 10
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 13
#       Dividend payout ratio (cp) (%): 13
#       Earnings retention ratio (%): 9
#       Enterprise value (cr.): 5
#       Ev/ebitda (x): 5
#
# Company: Kati Patang Lifestyle Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used in investing activities: 1
#       Foreign exchange gains / losses: 20
#       Net inc/dec in cash and cash equivalents: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Other income: 9
#       Operating and direct expenses: 4
#       Finance costs: 12
#       Current tax: 20
#       Deferred tax: 20
#       Total tax expenses: 16
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       depreciat: 18
#       Other income: 36
#       Interest: 40
#       Exceptional items: 43
#       Tax: 45
#       Diluted eps: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Return on networth / equity (%): 17
#       Dividend payout ratio (np) (%): 20
#       Dividend payout ratio (cp) (%): 20
#       Earnings retention ratio (%): 18
#
# Company: Kellton Tech Solutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 1
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1
#       Net cash used in investing activities: 1
#       Net cash used from financing activities: 3
#       Foreign exchange gains / losses: 20
#       Net inc/dec in cash and cash equivalents: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14
#       Finance costs: 3
#       Current tax: 8
#       Deferred tax: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 3
#       Exceptional items: 41
#       Tax: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 6
#       Dividend payout ratio (np) (%): 20
#       Dividend payout ratio (cp) (%): 20
#       Earnings retention ratio (%): 14
#
# Company: Kernex Microsystems (India) Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 13
#       Current tax: 13
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 38
#       Tax: 4
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 13
#       Dividend payout ratio (cp) (%): 13
#       Earnings retention ratio (%): 12
#       Enterprise value (cr.): 1
#       Ev/ebitda (x): 1
#
# Company: KPIT Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 5
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 2
#       Total income from operations: 2
#       Employees cost: 2
#       depreciat: 2
#       Other expenses: 1
#       P/l before other inc. , int., excpt. items & tax: 1
#       Other income: 3
#       P/l before int., excpt. items & tax: 1
#       Interest: 1
#       P/l before exceptional items & tax: 1
#       Exceptional items: 22
#       P/l before tax: 1
#       Tax: 2
#       P/l after tax from ordinary activities: 1
#       Net profit/(loss) for the period: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 4
#       Dividend payout ratio (np) (%): 1
#       Dividend payout ratio (cp) (%): 1
#       Earnings retention ratio (%): 1
#
# Company: Latent View Analytics Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 9
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 9
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 15
#       Diluted eps: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 7
#       Dividend payout ratio (np) (%): 9
#       Dividend payout ratio (cp) (%): 9
#       Earnings retention ratio (%): 9
#       Enterprise value (cr.): 6
#       Ev/ebitda (x): 6
#
# Company: LTIMindtree Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 2
#
#   Sheet Name: Profit_Loss
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 5
#       Interest: 1
#       Exceptional items: 39
#       Diluted eps: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 8
#       Enterprise value (cr.): 2
#       Ev/ebitda (x): 2
#
# Company: Mastek Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 2
#       Net cashflow from operating activities: 2
#       Net cash used in investing activities: 2
#       Net cash used from financing activities: 2
#       Foreign exchange gains / losses: 15
#       Net inc/dec in cash and cash equivalents: 2
#       Cash and cash equivalents begin of year: 2
#       Cash and cash equivalents end of year: 2
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14
#       Finance costs: 4
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 1
#       Exceptional items: 25
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 18
#       Dividend payout ratio (np) (%): 2
#       Dividend payout ratio (cp) (%): 2
#       Earnings retention ratio (%): 2
#
# Company: Megasoft Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 1
#       Revenue from operations [net]: 1
#       Total operating revenues: 1
#       Operating and direct expenses: 3
#       Current tax: 7
#       Deferred tax: 3
#       Total tax expenses: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 9
#       Total income from operations: 9
#       Exceptional items: 41
#       Tax: 28
#       Basic eps: 2
#       Diluted eps: 2
#       Basic eps.: 2
#       Diluted eps.: 2
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 1
#       Pbdit margin (%): 1
#       Pbit margin (%): 1
#       Pbt margin (%): 1
#       Net profit margin (%): 1
#       Dividend payout ratio (np) (%): 18
#       Dividend payout ratio (cp) (%): 18
#       Earnings retention ratio (%): 10
#
# Company: MphasiS Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 18
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 7
#
#   Sheet Name: Quarterly
#
#     Null Values:
#       Quarterly Results of MphasiS(in Rs. Cr.): 3
#
#     Zero Values:
#       Exceptional items: 39
#       Basic eps.: 2
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 9
#
# Company: Nettlinx Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 3
#       Net cashflow from operating activities: 3
#       Net cash used in investing activities: 3
#       Net cash used from financing activities: 3
#       Foreign exchange gains / losses: 20
#       Net inc/dec in cash and cash equivalents: 5
#       Cash and cash equivalents begin of year: 3
#       Cash and cash equivalents end of year: 3
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 6
#       Current tax: 7
#       Deferred tax: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 14
#       Exceptional items: 44
#       Tax: 11
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 1
#       Dividend payout ratio (np) (%): 19
#       Dividend payout ratio (cp) (%): 19
#       Earnings retention ratio (%): 13
#
# Company: Onward Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 8
#       Current tax: 6
#       Deferred tax: 1
#       Total tax expenses: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 45
#       Tax: 9
#       Diluted eps: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 3
#       Dividend payout ratio (np) (%): 11
#       Dividend payout ratio (cp) (%): 11
#       Earnings retention ratio (%): 6
#
# Company: Oracle Financial Services Software Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 2
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Finance costs: 15
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 22
#       Exceptional items: 42
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 20
#       Dividend payout ratio (np) (%): 10
#       Dividend payout ratio (cp) (%): 10
#       Earnings retention ratio (%): 2
#
# Company: Palred Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used from financing activities: 5
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 4
#       Revenue from operations [net]: 4
#       Total operating revenues: 4
#       Operating and direct expenses: 12
#       Finance costs: 8
#       Current tax: 12
#       Deferred tax: 12
#       Total tax expenses: 10
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 19
#       Total income from operations: 19
#       Employees cost: 1
#       depreciat: 2
#       P/l before other inc. , int., excpt. items & tax: 1
#       Interest: 39
#       Exceptional items: 34
#       Tax: 42
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 4
#       Pbdit margin (%): 4
#       Pbit margin (%): 4
#       Pbt margin (%): 4
#       Net profit margin (%): 4
#       Total debt/equity (x): 17
#       Dividend payout ratio (np) (%): 17
#       Dividend payout ratio (cp) (%): 17
#       Earnings retention ratio (%): 12
#
# Company: Persistent Systems Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1
#       Net cashflow from operating activities: 1
#       Net cash used in investing activities: 1
#       Net cash used from financing activities: 1
#       Foreign exchange gains / losses: 6
#       Net inc/dec in cash and cash equivalents: 1
#       Cash and cash equivalents begin of year: 1
#       Cash and cash equivalents end of year: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 1
#       Finance costs: 5
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 44
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 19
#       Enterprise value (cr.): 6
#       Ev/ebitda (x): 6
#
# Company: Protean eGov Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 5
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 5
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 10
#       Diluted eps: 2
#       Diluted eps.: 2
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 5
#       Enterprise value (cr.): 4
#       Ev/ebitda (x): 4
#
# Company: Quick Heal Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used from financing activities: 1
#       Foreign exchange gains / losses: 13
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 8
#       Finance costs: 12
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 36
#       Exceptional items: 29
#       Basic eps: 1
#       Diluted eps: 1
#       Basic eps.: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 14
#       Dividend payout ratio (np) (%): 2
#       Dividend payout ratio (cp) (%): 2
#       Earnings retention ratio (%): 1
#       Enterprise value (cr.): 5
#       Ev/ebitda (x): 5
#
# Company: R Systems International Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 7
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 17
#       Other expenses: 1
#       Deferred tax: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 40
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 11
#       Dividend payout ratio (np) (%): 6
#       Dividend payout ratio (cp) (%): 6
#       Earnings retention ratio (%): 4
#       Enterprise value (cr.): 2
#       Ev/ebitda (x): 2
#
# Company: Route Mobile Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 6
#
#   Sheet Name: Profit_Loss
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 16
#       Diluted eps: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 5
#       Dividend payout ratio (np) (%): 2
#       Dividend payout ratio (cp) (%): 2
#       Earnings retention ratio (%): 2
#       Enterprise value (cr.): 5
#       Ev/ebitda (x): 5
#
# Company: RPSG VENTURES Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used from financing activities: 2
#       Foreign exchange gains / losses: 5
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 5
#       Finance costs: 2
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       depreciat: 4
#       Interest: 13
#       Exceptional items: 24
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 2
#       Dividend payout ratio (np) (%): 5
#       Dividend payout ratio (cp) (%): 5
#       Earnings retention ratio (%): 5
#
# Company: Sasken Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 15
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14
#       Finance costs: 13
#       Deferred tax: 8
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 24
#       Exceptional items: 37
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 20
#       Enterprise value (cr.): 1
#       Ev/ebitda (x): 1
#
# Company: Saven Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used from financing activities: 3
#       Foreign exchange gains / losses: 11
#       Cash and cash equivalents begin of year: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 19
#       Finance costs: 10
#       Current tax: 6
#       Deferred tax: 14
#       Total tax expenses: 6
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 42
#       Exceptional items: 45
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 18
#       Dividend payout ratio (np) (%): 11
#       Dividend payout ratio (cp) (%): 11
#       Earnings retention ratio (%): 6
#
# Company: SBSJHVHSV Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1
#       Net cashflow from operating activities: 1
#       Net cash used in investing activities: 2
#       Net cash used from financing activities: 5
#       Foreign exchange gains / losses: 20
#       Net inc/dec in cash and cash equivalents: 1
#       Cash and cash equivalents begin of year: 1
#       Cash and cash equivalents end of year: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Other income: 3
#       Operating and direct expenses: 20
#       Finance costs: 10
#       Current tax: 8
#       Deferred tax: 3
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 3
#       Interest: 35
#       Exceptional items: 45
#       Basic eps: 1
#       Diluted eps: 1
#       Basic eps.: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 9
#       Dividend payout ratio (np) (%): 14
#       Dividend payout ratio (cp) (%): 14
#       Earnings retention ratio (%): 14
#       Enterprise value (cr.): 12
#       Ev/ebitda (x): 12
#
# Company: Securekloud Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 2
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 3
#       Revenue from operations [net]: 3
#       Total operating revenues: 3
#       Other income: 5
#       Total revenue: 2
#       Operating and direct expenses: 20
#       Employee benefit expenses: 3
#       Finance costs: 6
#       Depreciation and amortisation expenses: 6
#       Current tax: 9
#       Deferred tax: 8
#       Total tax expenses: 5
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other expenses: 13
#       Other income: 11
#       Interest: 1
#       Exceptional items: 43
#       Diluted eps: 1
#       Diluted eps.: 1
#
# Company: Shradha AI Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used from financing activities: 3
#       Foreign exchange gains / losses: 5
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 4
#       Finance costs: 4
#       Depreciation and amortisation expenses: 4
#       Deferred tax: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       depreciat: 6
#       Interest: 7
#       Exceptional items: 10
#       P/l after tax from ordinary activities: 1
#       Net profit/(loss) for the period: 1
#       Diluted eps: 4
#       Diluted eps.: 4
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 5
#       Dividend payout ratio (np) (%): 3
#       Dividend payout ratio (cp) (%): 3
#       Earnings retention ratio (%): 3
#       Enterprise value (cr.): 4
#       Ev/ebitda (x): 4
#
# Company: Sigma Solve Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 4
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 4
#       Finance costs: 2
#       Deferred tax: 2
#
#   Sheet Name: Quarterly
#
#     Zero Values:
# ...
#       Employee benefit expenses: 4
#       Finance costs: 5
#       Depreciation and amortisation expenses: 12
#       Profit/loss before exceptional, extraordinary items and tax: 3
#       Profit/loss before tax: 3
#       Current tax: 11
#       Deferred tax: 7
#       Total tax expenses: 4
#       Profit/loss after tax and before extraordinary items: 3
#       Profit/loss from continuing operations: 3
#       Profit/loss for the period: 3
#       Basic eps (rs.): 2
#       Diluted eps (rs.): 2
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 19
#       Total income from operations: 19
#       Employees cost: 29
#       depreciat: 45
#       Other expenses: 3
#       P/l before other inc. , int., excpt. items & tax: 7
#       Other income: 44
#       P/l before int., excpt. items & tax: 7
#       Interest: 22
#       P/l before exceptional items & tax: 4
#       Exceptional items: 45
#       P/l before tax: 4
#       Tax: 38
#       P/l after tax from ordinary activities: 4
#       Net profit/(loss) for the period: 4
#       Basic eps: 2
#       Diluted eps: 3
#       Basic eps.: 2
#       Diluted eps.: 3
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 4
#       Pbit/share (rs.): 2
#       Pbt/share (rs.): 2
#       Net profit/share (rs.): 2
#       Pbdit margin (%): 4
#       Pbit margin (%): 4
#       Pbt margin (%): 4
#       Net profit margin (%): 4
#       Return on networth / equity (%): 2
#       Return on assets (%): 2
#       Total debt/equity (x): 6
#       Dividend payout ratio (np) (%): 14
#       Dividend payout ratio (cp) (%): 14
#       Earnings retention ratio (%): 11
#       Enterprise value (cr.): 4
#       Ev/ebitda (x): 4
#
# Company: Softsol India Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used from financing activities: 9
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14
#       Finance costs: 4
#       Current tax: 1
#       Deferred tax: 14
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 13
#       Exceptional items: 45
#       Tax: 2
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 20
#       Dividend payout ratio (np) (%): 19
#       Dividend payout ratio (cp) (%): 19
#       Earnings retention ratio (%): 8
#
# Company: Sonata Software Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 8
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14
#       Finance costs: 4
#       Current tax: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 3
#       Exceptional items: 41
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 16
#
# Company: Starcom Information Technology Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 2
#       Total current liabilities: 1
#       Tangible assets: 7
#       Fixed assets: 7
#       Total non-current assets: 3
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used in investing activities: 2
#       Net cash used from financing activities: 4
#       Foreign exchange gains / losses: 19
#       Net inc/dec in cash and cash equivalents: 2
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 2
#       Revenue from operations [net]: 2
#       Total operating revenues: 2
#       Other income: 4
#       Operating and direct expenses: 19
#       Employee benefit expenses: 4
#       Finance costs: 7
#       Depreciation and amortisation expenses: 7
#       Current tax: 8
#       Deferred tax: 9
#       Total tax expenses: 3
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       P/l before other inc. , int., excpt. items & tax: 2
#       Other income: 8
#       P/l before int., excpt. items & tax: 1
#       Interest: 5
#       Exceptional items: 43
#       Tax: 16
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 2
#       Pbdit margin (%): 2
#       Pbit margin (%): 2
#       Pbt margin (%): 2
#       Net profit margin (%): 2
#       Return on networth / equity (%): 4
#       Total debt/equity (x): 5
#       Dividend payout ratio (np) (%): 19
#       Dividend payout ratio (cp) (%): 19
#       Earnings retention ratio (%): 15
#
# Company: Tata Consultancy Services Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 3
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 41
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 15
#
# Company: Tech Mahindra Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 3
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 12
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Finance costs: 2
#       Deferred tax: 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 43
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 11
#       Enterprise value (cr.): 2
#       Ev/ebitda (x): 2
#
# Company: Tera Software Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 8
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 42
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 8
#       Dividend payout ratio (cp) (%): 8
#       Earnings retention ratio (%): 8
#
# Company: Titan Intech Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 9
#       Total current liabilities: 6
#       Tangible assets: 1
#       Fixed assets: 1
#       Total non-current assets: 1
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 4
#       Net cashflow from operating activities: 3
#       Net cash used in investing activities: 7
#       Net cash used from financing activities: 10
#       Foreign exchange gains / losses: 15
#       Net inc/dec in cash and cash equivalents: 3
#       Cash and cash equivalents begin of year: 2
#       Cash and cash equivalents end of year: 2
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Other income: 14
#       Operating and direct expenses: 3
#       Employee benefit expenses: 3
#       Finance costs: 12
#       Depreciation and amortisation expenses: 1
#       Other expenses: 1
#       Profit/loss before exceptional, extraordinary items and tax: 4
#       Profit/loss before tax: 4
#       Current tax: 9
#       Deferred tax: 14
#       Total tax expenses: 8
#       Profit/loss after tax and before extraordinary items: 4
#       Profit/loss from continuing operations: 4
#       Profit/loss for the period: 4
#       Basic eps (rs.): 1
#       Diluted eps (rs.): 1
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 8
#       Total income from operations: 8
#       Other expenses: 5
#       P/l before other inc. , int., excpt. items & tax: 2
#       Other income: 44
#       P/l before int., excpt. items & tax: 2
#       Interest: 24
#       P/l before exceptional items & tax: 2
#       Exceptional items: 45
#       P/l before tax: 2
#       Tax: 23
#       P/l after tax from ordinary activities: 3
#       Net profit/(loss) for the period: 3
#       Basic eps: 3
#       Diluted eps: 3
#       Basic eps.: 3
#       Diluted eps.: 3
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Pbit/share (rs.): 1
#       Pbt/share (rs.): 1
#       Net profit/share (rs.): 1
#       Pbit margin (%): 1
#       Pbt margin (%): 1
#       Net profit margin (%): 1
#       Total debt/equity (x): 12
#       Dividend payout ratio (np) (%): 15
#       Dividend payout ratio (cp) (%): 15
#       Earnings retention ratio (%): 13
#
# Company: Trigyn Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 6
#       Finance costs: 3
#       Current tax: 8
#       Deferred tax: 8
#       Total tax expenses: 3
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 1
#       Exceptional items: 15
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 13
#       Dividend payout ratio (np) (%): 19
#       Dividend payout ratio (cp) (%): 19
#       Earnings retention ratio (%): 10
#
# Company: Unicommerce Esolutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used from financing activities: 4
#       Foreign exchange gains / losses: 5
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Finance costs: 4
#       Current tax: 1
#       Deferred tax: 2
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 5
#       Diluted eps: 1
#       Diluted eps.: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 5
#       Dividend payout ratio (np) (%): 5
#       Dividend payout ratio (cp) (%): 5
#       Earnings retention ratio (%): 5
#       Enterprise value (cr.): 5
#       Ev/ebitda (x): 5
#
# Company: USG Tech Solutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1
#       Net cashflow from operating activities: 1
#       Net cash used in investing activities: 2
#       Net cash used from financing activities: 3
#       Foreign exchange gains / losses: 20
#       Net inc/dec in cash and cash equivalents: 3
#       Cash and cash equivalents begin of year: 3
#       Cash and cash equivalents end of year: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 6
#       Revenue from operations [net]: 6
#       Total operating revenues: 6
#       Other income: 3
#       Total revenue: 3
#       Operating and direct expenses: 8
#       Employee benefit expenses: 1
#       Finance costs: 15
#       Current tax: 10
#       Deferred tax: 8
#       Total tax expenses: 7
#       Profit/loss after tax and before extraordinary items: 1
#       Profit/loss from continuing operations: 1
#       Profit/loss for the period: 1
#       Basic eps (rs.): 5
#       Diluted eps (rs.): 5
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 32
#       Total income from operations: 30
#       depreciat: 22
#       Other income: 27
#       P/l before int., excpt. items & tax: 1
#       Interest: 41
#       P/l before exceptional items & tax: 1
#       Exceptional items: 42
#       P/l before tax: 1
#       Tax: 38
#       P/l after tax from ordinary activities: 1
#       Net profit/(loss) for the period: 1
#       Basic eps: 16
#       Diluted eps: 20
#       Basic eps.: 16
#       Diluted eps.: 20
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 6
#       Pbdit/share (rs.): 1
#       Pbit/share (rs.): 2
#       Pbt/share (rs.): 2
#       Net profit/share (rs.): 3
#       Pbdit margin (%): 6
#       Pbit margin (%): 6
#       Pbt margin (%): 6
#       Net profit margin (%): 6
#       Return on networth / equity (%): 1
#       Return on assets (%): 1
#       Total debt/equity (x): 10
#       Dividend payout ratio (np) (%): 20
#       Dividend payout ratio (cp) (%): 20
#       Earnings retention ratio (%): 11
#
# Company: VEDAVAAG Systems Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used in investing activities: 1
#       Net cash used from financing activities: 1
#       Foreign exchange gains / losses: 19
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Other income: 2
#       Finance costs: 2
#       Deferred tax: 3
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Employees cost: 11
#       depreciat: 1
#       Other income: 22
#       Interest: 18
#       Exceptional items: 45
#       Tax: 2
#       Basic eps: 3
#       Diluted eps: 3
#       Basic eps.: 3
#       Diluted eps.: 3
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 6
#       Dividend payout ratio (np) (%): 14
#       Dividend payout ratio (cp) (%): 14
#       Earnings retention ratio (%): 4
#       Enterprise value (cr.): 3
#       Ev/ebitda (x): 3
#
# Company: WEP Solutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cashflow from operating activities: 1
#       Net cash used in investing activities: 1
#       Net cash used from financing activities: 1
#       Foreign exchange gains / losses: 20
#       Net inc/dec in cash and cash equivalents: 1
#       Cash and cash equivalents begin of year: 2
#       Cash and cash equivalents end of year: 3
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Other income: 1
#       Operating and direct expenses: 14
#       Finance costs: 4
#       Current tax: 8
#       Deferred tax: 6
#       Total tax expenses: 7
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       P/l before other inc. , int., excpt. items & tax: 1
#       Exceptional items: 45
#       Tax: 1
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 1
#       Dividend payout ratio (np) (%): 16
#       Dividend payout ratio (cp) (%): 16
#       Earnings retention ratio (%): 12
#
# Company: Wipro Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 6
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 8
#       Deferred tax: 3
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 45
#
#   Sheet Name: Ratio
#
# Company: Xchanging Solutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1
#       Net cashflow from operating activities: 1
#       Net cash used in investing activities: 1
#       Net cash used from financing activities: 1
#       Foreign exchange gains / losses: 20
#       Net inc/dec in cash and cash equivalents: 1
#       Cash and cash equivalents begin of year: 1
#       Cash and cash equivalents end of year: 1
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14
#       Current tax: 1
#       Deferred tax: 5
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       P/l before other inc. , int., excpt. items & tax: 1
#       Interest: 4
#       Exceptional items: 40
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 10
#       Dividend payout ratio (np) (%): 19
#       Dividend payout ratio (cp) (%): 19
#       Earnings retention ratio (%): 12
#
# Company: Xtglobal Infotech Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1
#       Net cashflow from operating activities: 1
#       Net cash used in investing activities: 7
#       Net cash used from financing activities: 10
#       Foreign exchange gains / losses: 20
#       Net inc/dec in cash and cash equivalents: 2
#       Cash and cash equivalents begin of year: 2
#       Cash and cash equivalents end of year: 2
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Other income: 6
#       Operating and direct expenses: 15
#       Finance costs: 8
#       Depreciation and amortisation expenses: 1
#       Current tax: 18
#       Deferred tax: 15
#       Total tax expenses: 15
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 4
#       Total income from operations: 4
#       Employees cost: 1
#       depreciat: 14
#       Other income: 23
#       Interest: 24
#       Exceptional items: 39
#       Tax: 26
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Return on networth / equity (%): 7
#       Total debt/equity (x): 2
#       Dividend payout ratio (np) (%): 20
#       Dividend payout ratio (cp) (%): 20
#       Earnings retention ratio (%): 20
#
# Company: Zensar Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 3
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used in investing activities: 1
#       Foreign exchange gains / losses: 15
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 6
#       Finance costs: 1
#       Current tax: 1
#       Deferred tax: 5
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 45
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 13

# %%
import os
import pandas as pd

# Define the base directory containing all company folders
input_file = r"C:\Users\rayya\OneDrive\Desktop\Programs\Financial-Management-Dataset-\Financial_Data\MoneyControl\Companies\IT Services & Consulting"
companies_list = os.listdir(input_file)

# Iterate over each company folder
for company in companies_list:
    file_path = os.path.join(input_file, company, "Pruned_Excel", "Final_Parameters", "Semi_Final")

    # Define file name
    excel_file = os.path.join(file_path, f"{company}_Semi_Final.xlsx")

    # Check if the file exists before processing
    if os.path.exists(excel_file):
        print(f"\nCompany: {company}")

        # Load all sheets from the Excel file
        dfs = pd.read_excel(excel_file, sheet_name=None)

        # Iterate through each sheet in the Excel file
        for sheet_name, df in dfs.items():
            print(f"\n  Sheet Name: {sheet_name}")

            # Count null values per column
            null_counts = df.isnull().sum()
            null_columns = null_counts[null_counts > 0]  # Only columns with nulls

            # Convert non-numeric columns to NaN (avoid counting 0s in text)
            df_numeric = df.apply(pd.to_numeric, errors='coerce')

            # Count occurrences of zero values per column
            zero_counts = (df_numeric == 0).sum()
            zero_columns = zero_counts[zero_counts > 0]  # Only columns with 0s

            # Display null values if any exist
            if not null_columns.empty:
                print("\n    Null Values:")
                for column, count in null_columns.items():
                    print(f"      {column}: {count}")

            # Display zero values with total column length
            if not zero_columns.empty:
                print("\n    Zero Values:")
                for column, count in zero_columns.items():
                    total_length = df_numeric[column].count() + df_numeric[column].isnull().sum()  # Total rows in the column
                    print(f"      {column}: {count} zeros (Column length: {total_length})")
# Out:
# Company: 3i Infotech Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 5 zeros (Column length: 20)
#       Current tax: 13 zeros (Column length: 20)
#       Deferred tax: 9 zeros (Column length: 20)
#       Total tax expenses: 5 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 14 zeros (Column length: 45)
#       Tax: 32 zeros (Column length: 45)
#       Diluted eps: 1 zeros (Column length: 45)
#       Diluted eps.: 1 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Return on networth / equity (%): 1 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 13 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 13 zeros (Column length: 20)
#       Earnings retention ratio (%): 13 zeros (Column length: 20)
#       Enterprise value (cr.): 1 zeros (Column length: 20)
#       Ev/ebitda (x): 1 zeros (Column length: 20)
#
# Company: Adroit Infotech Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 2 zeros (Column length: 20)
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used in investing activities: 5 zeros (Column length: 20)
#       Net cash used from financing activities: 8 zeros (Column length: 20)
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 4 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 1 zeros (Column length: 20)
#       Revenue from operations [net]: 1 zeros (Column length: 20)
#       Total operating revenues: 1 zeros (Column length: 20)
#       Other income: 5 zeros (Column length: 20)
#       Operating and direct expenses: 12 zeros (Column length: 20)
#       Employee benefit expenses: 2 zeros (Column length: 20)
#       Finance costs: 7 zeros (Column length: 20)
#       Current tax: 15 zeros (Column length: 20)
#       Deferred tax: 9 zeros (Column length: 20)
#       Total tax expenses: 6 zeros (Column length: 20)
#       Profit/loss after tax and before extraordinary items: 2 zeros (Column length: 20)
#       Profit/loss from continuing operations: 1 zeros (Column length: 20)
#       Profit/loss for the period: 1 zeros (Column length: 20)
#       Basic eps (rs.): 2 zeros (Column length: 20)
#       Diluted eps (rs.): 2 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 2 zeros (Column length: 45)
#       Total income from operations: 1 zeros (Column length: 45)
#       Employees cost: 2 zeros (Column length: 45)
#       depreciat: 4 zeros (Column length: 45)
#       Other income: 18 zeros (Column length: 45)
#       Interest: 15 zeros (Column length: 45)
#       Exceptional items: 41 zeros (Column length: 45)
#       Tax: 28 zeros (Column length: 45)
#       Basic eps: 3 zeros (Column length: 45)
#       Diluted eps: 3 zeros (Column length: 45)
#       Basic eps.: 3 zeros (Column length: 45)
#       Diluted eps.: 3 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 1 zeros (Column length: 20)
#       Pbt/share (rs.): 1 zeros (Column length: 20)
#       Net profit/share (rs.): 2 zeros (Column length: 20)
#       Pbdit margin (%): 1 zeros (Column length: 20)
#       Pbit margin (%): 1 zeros (Column length: 20)
#       Pbt margin (%): 1 zeros (Column length: 20)
#       Net profit margin (%): 1 zeros (Column length: 20)
#       Total debt/equity (x): 9 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 19 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 19 zeros (Column length: 20)
#       Earnings retention ratio (%): 19 zeros (Column length: 20)
#
# Company: Affle India Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 8 zeros (Column length: 10)
#
#   Sheet Name: Profit_Loss
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 25 zeros (Column length: 25)
#       Basic eps: 1 zeros (Column length: 25)
#       Diluted eps: 1 zeros (Column length: 25)
#       Basic eps.: 2 zeros (Column length: 25)
#       Diluted eps.: 1 zeros (Column length: 25)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 8 zeros (Column length: 10)
#       Dividend payout ratio (np) (%): 10 zeros (Column length: 10)
#       Dividend payout ratio (cp) (%): 10 zeros (Column length: 10)
#       Earnings retention ratio (%): 10 zeros (Column length: 10)
#       Enterprise value (cr.): 5 zeros (Column length: 10)
#       Ev/ebitda (x): 5 zeros (Column length: 10)
#
# Company: AION-TECH SOLUTIONS Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 1 zeros (Column length: 20)
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 6 zeros (Column length: 20)
#       Current tax: 4 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 7 zeros (Column length: 45)
#       Exceptional items: 44 zeros (Column length: 45)
#       Tax: 7 zeros (Column length: 45)
#       Basic eps: 1 zeros (Column length: 45)
#       Diluted eps: 2 zeros (Column length: 45)
#       Basic eps.: 1 zeros (Column length: 45)
#       Diluted eps.: 2 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 2 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 19 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 19 zeros (Column length: 20)
#       Earnings retention ratio (%): 10 zeros (Column length: 20)
#
# Company: Allied Digital Services Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1 zeros (Column length: 20)
#       Net cashflow from operating activities: 1 zeros (Column length: 20)
#       Net cash used in investing activities: 1 zeros (Column length: 20)
#       Net cash used from financing activities: 1 zeros (Column length: 20)
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 1 zeros (Column length: 20)
#       Cash and cash equivalents begin of year: 1 zeros (Column length: 20)
#       Cash and cash equivalents end of year: 1 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 7 zeros (Column length: 20)
#       Current tax: 1 zeros (Column length: 20)
#       Deferred tax: 1 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 43 zeros (Column length: 45)
#       Tax: 7 zeros (Column length: 45)
#       Basic eps: 1 zeros (Column length: 45)
#       Diluted eps: 1 zeros (Column length: 45)
#       Basic eps.: 1 zeros (Column length: 45)
#       Diluted eps.: 1 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 12 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 12 zeros (Column length: 20)
#       Earnings retention ratio (%): 6 zeros (Column length: 20)
#       Enterprise value (cr.): 3 zeros (Column length: 20)
#       Ev/ebitda (x): 3 zeros (Column length: 20)
#
# Company: Alphalogic Techsys Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 5 zeros (Column length: 5)
#       Net inc/dec in cash and cash equivalents: 4 zeros (Column length: 5)
#       Cash and cash equivalents begin of year: 1 zeros (Column length: 5)
#       Cash and cash equivalents end of year: 1 zeros (Column length: 5)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 2 zeros (Column length: 5)
#       Deferred tax: 3 zeros (Column length: 5)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       depreciat: 7 zeros (Column length: 10)
#       Exceptional items: 10 zeros (Column length: 10)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 5 zeros (Column length: 5)
#       Dividend payout ratio (cp) (%): 5 zeros (Column length: 5)
#       Earnings retention ratio (%): 5 zeros (Column length: 5)
#
# Company: ASM Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 11 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 1 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 8 zeros (Column length: 20)
#       Current tax: 2 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 44 zeros (Column length: 45)
#       Diluted eps: 1 zeros (Column length: 45)
#       Diluted eps.: 1 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 3 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 3 zeros (Column length: 20)
#
# Company: Atishay Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 15 zeros (Column length: 15)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 1 zeros (Column length: 15)
#       Current tax: 1 zeros (Column length: 15)
#       Deferred tax: 3 zeros (Column length: 15)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 34 zeros (Column length: 35)
#       Tax: 1 zeros (Column length: 35)
#       Basic eps: 1 zeros (Column length: 35)
#       Diluted eps: 1 zeros (Column length: 35)
#       Basic eps.: 1 zeros (Column length: 35)
#       Diluted eps.: 1 zeros (Column length: 35)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 1 zeros (Column length: 15)
#       Dividend payout ratio (np) (%): 10 zeros (Column length: 15)
#       Dividend payout ratio (cp) (%): 10 zeros (Column length: 15)
#       Earnings retention ratio (%): 7 zeros (Column length: 15)
#       Enterprise value (cr.): 5 zeros (Column length: 15)
#       Ev/ebitda (x): 5 zeros (Column length: 15)
#
# Company: Avance Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 2 zeros (Column length: 15)
#       Tangible assets: 9 zeros (Column length: 15)
#       Fixed assets: 9 zeros (Column length: 15)
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1 zeros (Column length: 15)
#       Net cashflow from operating activities: 1 zeros (Column length: 15)
#       Net cash used in investing activities: 1 zeros (Column length: 15)
#       Net cash used from financing activities: 6 zeros (Column length: 15)
#       Foreign exchange gains / losses: 15 zeros (Column length: 15)
#       Net inc/dec in cash and cash equivalents: 1 zeros (Column length: 15)
#       Cash and cash equivalents begin of year: 1 zeros (Column length: 15)
#       Cash and cash equivalents end of year: 1 zeros (Column length: 15)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 12 zeros (Column length: 15)
#       Employee benefit expenses: 1 zeros (Column length: 15)
#       Finance costs: 12 zeros (Column length: 15)
#       Depreciation and amortisation expenses: 9 zeros (Column length: 15)
#       Current tax: 8 zeros (Column length: 15)
#       Deferred tax: 10 zeros (Column length: 15)
#       Total tax expenses: 6 zeros (Column length: 15)
#       Basic eps (rs.): 4 zeros (Column length: 15)
#       Diluted eps (rs.): 4 zeros (Column length: 15)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 6 zeros (Column length: 45)
#       Total income from operations: 4 zeros (Column length: 45)
#       Employees cost: 10 zeros (Column length: 45)
#       depreciat: 37 zeros (Column length: 45)
#       Other expenses: 5 zeros (Column length: 45)
#       P/l before other inc. , int., excpt. items & tax: 1 zeros (Column length: 45)
#       Other income: 31 zeros (Column length: 45)
#       P/l before int., excpt. items & tax: 1 zeros (Column length: 45)
#       Interest: 41 zeros (Column length: 45)
#       P/l before exceptional items & tax: 1 zeros (Column length: 45)
#       Exceptional items: 35 zeros (Column length: 45)
#       Tax: 40 zeros (Column length: 45)
#       Basic eps: 27 zeros (Column length: 45)
#       Diluted eps: 27 zeros (Column length: 45)
#       Basic eps.: 26 zeros (Column length: 45)
#       Diluted eps.: 26 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 1 zeros (Column length: 15)
#       Pbdit/share (rs.): 5 zeros (Column length: 15)
#       Pbit/share (rs.): 5 zeros (Column length: 15)
#       Pbt/share (rs.): 2 zeros (Column length: 15)
#       Net profit/share (rs.): 3 zeros (Column length: 15)
#       Total debt/equity (x): 8 zeros (Column length: 15)
#       Dividend payout ratio (np) (%): 15 zeros (Column length: 15)
#       Dividend payout ratio (cp) (%): 15 zeros (Column length: 15)
#       Earnings retention ratio (%): 13 zeros (Column length: 15)
#
# Company: Bartronics India Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 1 zeros (Column length: 20)
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1 zeros (Column length: 20)
#       Net cashflow from operating activities: 1 zeros (Column length: 20)
#       Net cash used in investing activities: 1 zeros (Column length: 20)
#       Net cash used from financing activities: 2 zeros (Column length: 20)
#       Foreign exchange gains / losses: 19 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 2 zeros (Column length: 20)
#       Cash and cash equivalents begin of year: 2 zeros (Column length: 20)
#       Cash and cash equivalents end of year: 2 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 16 zeros (Column length: 20)
#       Finance costs: 1 zeros (Column length: 20)
#       Current tax: 12 zeros (Column length: 20)
#       Deferred tax: 2 zeros (Column length: 20)
#       Diluted eps (rs.): 1 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 4 zeros (Column length: 45)
#       Interest: 7 zeros (Column length: 45)
#       Exceptional items: 38 zeros (Column length: 45)
#       Tax: 1 zeros (Column length: 45)
#       Basic eps: 2 zeros (Column length: 45)
#       Diluted eps: 3 zeros (Column length: 45)
#       Basic eps.: 3 zeros (Column length: 45)
#       Diluted eps.: 3 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Return on networth / equity (%): 3 zeros (Column length: 20)
#       Total debt/equity (x): 1 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 17 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 17 zeros (Column length: 20)
#       Earnings retention ratio (%): 12 zeros (Column length: 20)
#       Enterprise value (cr.): 2 zeros (Column length: 20)
#       Ev/ebitda (x): 2 zeros (Column length: 20)
#
# Company: Birlasoft Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 6 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 43 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 5 zeros (Column length: 20)
#
# Company: Cambridge Technology Enterprises Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1 zeros (Column length: 20)
#       Net cashflow from operating activities: 1 zeros (Column length: 20)
#       Net cash used in investing activities: 1 zeros (Column length: 20)
#       Net cash used from financing activities: 3 zeros (Column length: 20)
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 1 zeros (Column length: 20)
#       Cash and cash equivalents begin of year: 1 zeros (Column length: 20)
#       Cash and cash equivalents end of year: 1 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Other income: 1 zeros (Column length: 20)
#       Operating and direct expenses: 2 zeros (Column length: 20)
#       Employee benefit expenses: 1 zeros (Column length: 20)
#       Finance costs: 2 zeros (Column length: 20)
#       Other expenses: 1 zeros (Column length: 20)
#       Current tax: 9 zeros (Column length: 20)
#       Deferred tax: 5 zeros (Column length: 20)
#       Total tax expenses: 3 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 12 zeros (Column length: 45)
#       Exceptional items: 42 zeros (Column length: 45)
#       Tax: 2 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 6 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 19 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 19 zeros (Column length: 20)
#       Earnings retention ratio (%): 13 zeros (Column length: 20)
#       Enterprise value (cr.): 2 zeros (Column length: 20)
#       Ev/ebitda (x): 2 zeros (Column length: 20)
#
# Company: CG-Vak Software and Exports Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 1 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14 zeros (Column length: 20)
#       Employee benefit expenses: 2 zeros (Column length: 20)
#       Finance costs: 1 zeros (Column length: 20)
#       Current tax: 4 zeros (Column length: 20)
#       Deferred tax: 3 zeros (Column length: 20)
#       Total tax expenses: 1 zeros (Column length: 20)
#       Profit/loss from continuing operations: 1 zeros (Column length: 20)
#       Profit/loss for the period: 1 zeros (Column length: 20)
#       Basic eps (rs.): 1 zeros (Column length: 20)
#       Diluted eps (rs.): 1 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 1 zeros (Column length: 45)
#       Interest: 17 zeros (Column length: 45)
#       Exceptional items: 45 zeros (Column length: 45)
#       Tax: 1 zeros (Column length: 45)
#       P/l after tax from ordinary activities: 1 zeros (Column length: 45)
#       Net profit/(loss) for the period: 1 zeros (Column length: 45)
#       Basic eps: 1 zeros (Column length: 45)
#       Diluted eps: 1 zeros (Column length: 45)
#       Basic eps.: 1 zeros (Column length: 45)
#       Diluted eps.: 1 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Net profit/share (rs.): 1 zeros (Column length: 20)
#       Total debt/equity (x): 5 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 8 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 8 zeros (Column length: 20)
#       Earnings retention ratio (%): 4 zeros (Column length: 20)
#
# Company: COFORGE LIMITED Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14 zeros (Column length: 20)
#       Current tax: 1 zeros (Column length: 20)
#       Deferred tax: 1 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 39 zeros (Column length: 45)
#       Diluted eps: 1 zeros (Column length: 45)
#       Diluted eps.: 1 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 5 zeros (Column length: 20)
#
# Company: Cranes Software International Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 1 zeros (Column length: 20)
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cashflow from operating activities: 1 zeros (Column length: 20)
#       Net cash used in investing activities: 2 zeros (Column length: 20)
#       Net cash used from financing activities: 2 zeros (Column length: 20)
#       Foreign exchange gains / losses: 18 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 1 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 2 zeros (Column length: 20)
#       Revenue from operations [net]: 2 zeros (Column length: 20)
#       Total operating revenues: 2 zeros (Column length: 20)
#       Other income: 1 zeros (Column length: 20)
#       Total revenue: 1 zeros (Column length: 20)
#       Operating and direct expenses: 6 zeros (Column length: 20)
#       Finance costs: 1 zeros (Column length: 20)
#       Current tax: 14 zeros (Column length: 20)
#       Deferred tax: 1 zeros (Column length: 20)
#       Total tax expenses: 1 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 11 zeros (Column length: 45)
#       Total income from operations: 11 zeros (Column length: 45)
#       depreciat: 1 zeros (Column length: 45)
#       Other income: 10 zeros (Column length: 45)
#       Interest: 13 zeros (Column length: 45)
#       Exceptional items: 36 zeros (Column length: 45)
#       Tax: 7 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 2 zeros (Column length: 20)
#       Pbdit margin (%): 2 zeros (Column length: 20)
#       Pbit margin (%): 2 zeros (Column length: 20)
#       Pbt margin (%): 2 zeros (Column length: 20)
#       Net profit margin (%): 2 zeros (Column length: 20)
#       Return on networth / equity (%): 11 zeros (Column length: 20)
#       Total debt/equity (x): 8 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 15 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 15 zeros (Column length: 20)
#       Earnings retention ratio (%): 15 zeros (Column length: 20)
#
# Company: Cressanda Solution Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 1 zeros (Column length: 20)
#       Total current liabilities: 1 zeros (Column length: 20)
#       Tangible assets: 8 zeros (Column length: 20)
#       Fixed assets: 8 zeros (Column length: 20)
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1 zeros (Column length: 20)
#       Net cash used in investing activities: 9 zeros (Column length: 20)
#       Net cash used from financing activities: 8 zeros (Column length: 20)
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 3 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 8 zeros (Column length: 20)
#       Revenue from operations [net]: 8 zeros (Column length: 20)
#       Total operating revenues: 8 zeros (Column length: 20)
#       Other income: 4 zeros (Column length: 20)
#       Total revenue: 3 zeros (Column length: 20)
#       Operating and direct expenses: 13 zeros (Column length: 20)
#       Employee benefit expenses: 1 zeros (Column length: 20)
#       Finance costs: 14 zeros (Column length: 20)
#       Depreciation and amortisation expenses: 9 zeros (Column length: 20)
#       Profit/loss before exceptional, extraordinary items and tax: 1 zeros (Column length: 20)
#       Profit/loss before tax: 1 zeros (Column length: 20)
#       Current tax: 15 zeros (Column length: 20)
#       Deferred tax: 20 zeros (Column length: 20)
#       Total tax expenses: 11 zeros (Column length: 20)
#       Profit/loss after tax and before extraordinary items: 1 zeros (Column length: 20)
#       Profit/loss from continuing operations: 1 zeros (Column length: 20)
#       Profit/loss for the period: 1 zeros (Column length: 20)
#       Basic eps (rs.): 5 zeros (Column length: 20)
#       Diluted eps (rs.): 5 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 27 zeros (Column length: 45)
#       Total income from operations: 27 zeros (Column length: 45)
#       Employees cost: 11 zeros (Column length: 45)
#       depreciat: 39 zeros (Column length: 45)
#       Other expenses: 8 zeros (Column length: 45)
#       P/l before other inc. , int., excpt. items & tax: 2 zeros (Column length: 45)
#       Other income: 27 zeros (Column length: 45)
#       P/l before int., excpt. items & tax: 3 zeros (Column length: 45)
#       Interest: 43 zeros (Column length: 45)
#       P/l before exceptional items & tax: 3 zeros (Column length: 45)
#       Exceptional items: 39 zeros (Column length: 45)
#       P/l before tax: 3 zeros (Column length: 45)
#       Tax: 33 zeros (Column length: 45)
#       P/l after tax from ordinary activities: 3 zeros (Column length: 45)
#       Net profit/(loss) for the period: 3 zeros (Column length: 45)
#       Basic eps: 30 zeros (Column length: 45)
#       Diluted eps: 30 zeros (Column length: 45)
#       Basic eps.: 30 zeros (Column length: 45)
#       Diluted eps.: 30 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 9 zeros (Column length: 20)
#       Pbdit/share (rs.): 5 zeros (Column length: 20)
#       Pbit/share (rs.): 4 zeros (Column length: 20)
#       Pbt/share (rs.): 4 zeros (Column length: 20)
#       Net profit/share (rs.): 4 zeros (Column length: 20)
#       Pbdit margin (%): 8 zeros (Column length: 20)
#       Pbit margin (%): 8 zeros (Column length: 20)
#       Pbt margin (%): 8 zeros (Column length: 20)
#       Net profit margin (%): 8 zeros (Column length: 20)
#       Total debt/equity (x): 12 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 20 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 20 zeros (Column length: 20)
#       Earnings retention ratio (%): 17 zeros (Column length: 20)
#
# Company: Cybertech Systems and Software Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used from financing activities: 1 zeros (Column length: 20)
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Finance costs: 4 zeros (Column length: 20)
#       Current tax: 2 zeros (Column length: 20)
#       Deferred tax: 4 zeros (Column length: 20)
#       Total tax expenses: 1 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 1 zeros (Column length: 45)
#       Exceptional items: 44 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Pbit/share (rs.): 1 zeros (Column length: 20)
#       Pbt/share (rs.): 1 zeros (Column length: 20)
#       Total debt/equity (x): 8 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 2 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 2 zeros (Column length: 20)
#       Earnings retention ratio (%): 1 zeros (Column length: 20)
#
# Company: Cyient Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 2 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 1 zeros (Column length: 45)
#       Exceptional items: 41 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 17 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 1 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 1 zeros (Column length: 20)
#       Earnings retention ratio (%): 1 zeros (Column length: 20)
#
# Company: Danlaw Technologies India Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cashflow from operating activities: 1 zeros (Column length: 20)
#       Net cash used in investing activities: 1 zeros (Column length: 20)
#       Net cash used from financing activities: 8 zeros (Column length: 20)
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14 zeros (Column length: 20)
#       Finance costs: 5 zeros (Column length: 20)
#       Current tax: 9 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       P/l before other inc. , int., excpt. items & tax: 1 zeros (Column length: 45)
#       Interest: 19 zeros (Column length: 45)
#       Exceptional items: 45 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 13 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 20 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 20 zeros (Column length: 20)
#       Earnings retention ratio (%): 14 zeros (Column length: 20)
#
# Company: Datamatics Global Services Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used from financing activities: 1 zeros (Column length: 20)
#       Foreign exchange gains / losses: 13 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 1 zeros (Column length: 20)
#       Finance costs: 3 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 38 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 7 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 1 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 1 zeros (Column length: 20)
#       Earnings retention ratio (%): 1 zeros (Column length: 20)
#
# Company: Dev Information Technology Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 10 zeros (Column length: 10)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 4 zeros (Column length: 10)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 15 zeros (Column length: 15)
#       Diluted eps: 1 zeros (Column length: 15)
#       Diluted eps.: 1 zeros (Column length: 15)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 1 zeros (Column length: 10)
#       Dividend payout ratio (cp) (%): 1 zeros (Column length: 10)
#       Earnings retention ratio (%): 1 zeros (Column length: 10)
#       Enterprise value (cr.): 3 zeros (Column length: 10)
#       Ev/ebitda (x): 3 zeros (Column length: 10)
#
# Company: Dynacons Systems and Solutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 3 zeros (Column length: 20)
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Other income: 2 zeros (Column length: 20)
#       Total tax expenses: 1 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 16 zeros (Column length: 45)
#       Exceptional items: 45 zeros (Column length: 45)
#       P/l after tax from ordinary activities: 1 zeros (Column length: 45)
#       Net profit/(loss) for the period: 1 zeros (Column length: 45)
#       Basic eps: 1 zeros (Column length: 45)
#       Diluted eps: 1 zeros (Column length: 45)
#       Basic eps.: 1 zeros (Column length: 45)
#       Diluted eps.: 1 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 15 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 15 zeros (Column length: 20)
#       Earnings retention ratio (%): 7 zeros (Column length: 20)
#
# Company: Elnet Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 20 zeros (Column length: 20)
#       Finance costs: 3 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 15 zeros (Column length: 45)
#       Exceptional items: 43 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 3 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 3 zeros (Column length: 20)
#       Earnings retention ratio (%): 3 zeros (Column length: 20)
#
# Company: Equippp Social Impact Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used in investing activities: 4 zeros (Column length: 20)
#       Foreign exchange gains / losses: 16 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 2 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 3 zeros (Column length: 20)
#       Revenue from operations [net]: 3 zeros (Column length: 20)
#       Total operating revenues: 3 zeros (Column length: 20)
#       Other income: 3 zeros (Column length: 20)
#       Total revenue: 2 zeros (Column length: 20)
#       Operating and direct expenses: 11 zeros (Column length: 20)
#       Finance costs: 2 zeros (Column length: 20)
#       Current tax: 11 zeros (Column length: 20)
#       Deferred tax: 13 zeros (Column length: 20)
#       Total tax expenses: 10 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 16 zeros (Column length: 45)
#       Total income from operations: 16 zeros (Column length: 45)
#       depreciat: 28 zeros (Column length: 45)
#       Other expenses: 1 zeros (Column length: 45)
#       Other income: 34 zeros (Column length: 45)
#       Interest: 12 zeros (Column length: 45)
#       Exceptional items: 43 zeros (Column length: 45)
#       Tax: 43 zeros (Column length: 45)
#       Basic eps: 4 zeros (Column length: 45)
#       Diluted eps: 5 zeros (Column length: 45)
#       Basic eps.: 4 zeros (Column length: 45)
#       Diluted eps.: 5 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 3 zeros (Column length: 20)
#       Pbit/share (rs.): 1 zeros (Column length: 20)
#       Pbdit margin (%): 3 zeros (Column length: 20)
#       Pbit margin (%): 3 zeros (Column length: 20)
#       Pbt margin (%): 3 zeros (Column length: 20)
#       Net profit margin (%): 3 zeros (Column length: 20)
#       Return on networth / equity (%): 7 zeros (Column length: 20)
#       Total debt/equity (x): 4 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 16 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 16 zeros (Column length: 20)
#       Earnings retention ratio (%): 16 zeros (Column length: 20)
#       Enterprise value (cr.): 2 zeros (Column length: 20)
#       Ev/ebitda (x): 2 zeros (Column length: 20)
#
# Company: Expleo Solutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 3 zeros (Column length: 20)
#       Net cashflow from operating activities: 3 zeros (Column length: 20)
#       Net cash used in investing activities: 3 zeros (Column length: 20)
#       Net cash used from financing activities: 3 zeros (Column length: 20)
#       Foreign exchange gains / losses: 8 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 3 zeros (Column length: 20)
#       Cash and cash equivalents begin of year: 3 zeros (Column length: 20)
#       Cash and cash equivalents end of year: 3 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 6 zeros (Column length: 20)
#       Finance costs: 3 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 10 zeros (Column length: 45)
#       Exceptional items: 44 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 16 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 5 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 5 zeros (Column length: 20)
#       Earnings retention ratio (%): 5 zeros (Column length: 20)
#       Enterprise value (cr.): 5 zeros (Column length: 20)
#       Ev/ebitda (x): 5 zeros (Column length: 20)
#
# Company: FCS Software Solutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 11 zeros (Column length: 20)
#       Other expenses: 4 zeros (Column length: 20)
#       Deferred tax: 1 zeros (Column length: 20)
#       Basic eps (rs.): 1 zeros (Column length: 20)
#       Diluted eps (rs.): 1 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other expenses: 9 zeros (Column length: 45)
#       Interest: 3 zeros (Column length: 45)
#       Exceptional items: 32 zeros (Column length: 45)
#       Tax: 1 zeros (Column length: 45)
#       P/l after tax from ordinary activities: 2 zeros (Column length: 45)
#       Net profit/(loss) for the period: 2 zeros (Column length: 45)
#       Basic eps: 23 zeros (Column length: 45)
#       Diluted eps: 25 zeros (Column length: 45)
#       Basic eps.: 24 zeros (Column length: 45)
#       Diluted eps.: 26 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Pbit/share (rs.): 1 zeros (Column length: 20)
#       Pbt/share (rs.): 2 zeros (Column length: 20)
#       Net profit/share (rs.): 1 zeros (Column length: 20)
#       Total debt/equity (x): 4 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 16 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 16 zeros (Column length: 20)
#       Earnings retention ratio (%): 15 zeros (Column length: 20)
#
# Company: Genesys International Corporation Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 5 zeros (Column length: 20)
#       Current tax: 5 zeros (Column length: 20)
#       Deferred tax: 5 zeros (Column length: 20)
#       Total tax expenses: 1 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 43 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 2 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 7 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 7 zeros (Column length: 20)
#       Earnings retention ratio (%): 6 zeros (Column length: 20)
#
# Company: Happiest Minds Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 5 zeros (Column length: 5)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 15 zeros (Column length: 20)
#       Tax: 1 zeros (Column length: 20)
#       Diluted eps: 1 zeros (Column length: 20)
#       Diluted eps.: 1 zeros (Column length: 20)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 2 zeros (Column length: 5)
#       Dividend payout ratio (cp) (%): 2 zeros (Column length: 5)
#       Earnings retention ratio (%): 2 zeros (Column length: 5)
#       Enterprise value (cr.): 1 zeros (Column length: 5)
#       Ev/ebitda (x): 1 zeros (Column length: 5)
#
# Company: HCL Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 3 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 6 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 45 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 10 zeros (Column length: 20)
#
# Company: Indian Infotech and Software Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 9 zeros (Column length: 20)
#       Total current liabilities: 2 zeros (Column length: 20)
#       Tangible assets: 7 zeros (Column length: 20)
#       Fixed assets: 4 zeros (Column length: 20)
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1 zeros (Column length: 20)
#       Net cashflow from operating activities: 1 zeros (Column length: 20)
#       Net cash used in investing activities: 6 zeros (Column length: 20)
#       Net cash used from financing activities: 3 zeros (Column length: 20)
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 2 zeros (Column length: 20)
#       Cash and cash equivalents begin of year: 2 zeros (Column length: 20)
#       Cash and cash equivalents end of year: 1 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 1 zeros (Column length: 20)
#       Revenue from operations [net]: 1 zeros (Column length: 20)
#       Total operating revenues: 1 zeros (Column length: 20)
#       Other income: 6 zeros (Column length: 20)
#       Operating and direct expenses: 15 zeros (Column length: 20)
#       Employee benefit expenses: 1 zeros (Column length: 20)
#       Finance costs: 13 zeros (Column length: 20)
#       Depreciation and amortisation expenses: 6 zeros (Column length: 20)
#       Profit/loss before exceptional, extraordinary items and tax: 1 zeros (Column length: 20)
#       Profit/loss before tax: 1 zeros (Column length: 20)
#       Current tax: 11 zeros (Column length: 20)
#       Deferred tax: 14 zeros (Column length: 20)
#       Total tax expenses: 6 zeros (Column length: 20)
#       Profit/loss after tax and before extraordinary items: 1 zeros (Column length: 20)
#       Profit/loss from continuing operations: 1 zeros (Column length: 20)
#       Profit/loss for the period: 1 zeros (Column length: 20)
#       Basic eps (rs.): 5 zeros (Column length: 20)
#       Diluted eps (rs.): 5 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Employees cost: 2 zeros (Column length: 45)
#       depreciat: 22 zeros (Column length: 45)
#       Other income: 42 zeros (Column length: 45)
#       Interest: 41 zeros (Column length: 45)
#       Exceptional items: 45 zeros (Column length: 45)
#       Tax: 24 zeros (Column length: 45)
#       Basic eps: 10 zeros (Column length: 45)
#       Diluted eps: 10 zeros (Column length: 45)
#       Basic eps.: 10 zeros (Column length: 45)
#       Diluted eps.: 10 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 2 zeros (Column length: 20)
#       Pbdit/share (rs.): 3 zeros (Column length: 20)
#       Pbit/share (rs.): 7 zeros (Column length: 20)
#       Pbt/share (rs.): 7 zeros (Column length: 20)
#       Net profit/share (rs.): 5 zeros (Column length: 20)
#       Pbdit margin (%): 1 zeros (Column length: 20)
#       Pbit margin (%): 1 zeros (Column length: 20)
#       Pbt margin (%): 1 zeros (Column length: 20)
#       Net profit margin (%): 1 zeros (Column length: 20)
#       Total debt/equity (x): 14 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 20 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 20 zeros (Column length: 20)
#       Earnings retention ratio (%): 16 zeros (Column length: 20)
#
# Company: Infosys Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Finance costs: 15 zeros (Column length: 20)
#       Deferred tax: 2 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 22 zeros (Column length: 45)
#       Exceptional items: 44 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 20 zeros (Column length: 20)
#
# Company: Inspirisys Solutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1 zeros (Column length: 20)
#       Net cashflow from operating activities: 1 zeros (Column length: 20)
#       Net cash used in investing activities: 1 zeros (Column length: 20)
#       Net cash used from financing activities: 1 zeros (Column length: 20)
#       Foreign exchange gains / losses: 19 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 1 zeros (Column length: 20)
#       Cash and cash equivalents begin of year: 1 zeros (Column length: 20)
#       Cash and cash equivalents end of year: 1 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 19 zeros (Column length: 20)
#       Current tax: 2 zeros (Column length: 20)
#       Deferred tax: 8 zeros (Column length: 20)
#       Total tax expenses: 1 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Employees cost: 4 zeros (Column length: 45)
#       Exceptional items: 42 zeros (Column length: 45)
#       Tax: 9 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Return on networth / equity (%): 2 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 12 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 12 zeros (Column length: 20)
#       Earnings retention ratio (%): 12 zeros (Column length: 20)
#       Enterprise value (cr.): 2 zeros (Column length: 20)
#       Ev/ebitda (x): 2 zeros (Column length: 20)
#
# Company: Intellect Design Arena Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 2 zeros (Column length: 10)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 8 zeros (Column length: 10)
#       Finance costs: 1 zeros (Column length: 10)
#       Current tax: 3 zeros (Column length: 10)
#       Deferred tax: 1 zeros (Column length: 10)
#       Total tax expenses: 1 zeros (Column length: 10)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Interest: 5 zeros (Column length: 40)
#       Exceptional items: 39 zeros (Column length: 40)
#       Tax: 13 zeros (Column length: 40)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 4 zeros (Column length: 10)
#       Dividend payout ratio (np) (%): 8 zeros (Column length: 10)
#       Dividend payout ratio (cp) (%): 8 zeros (Column length: 10)
#       Earnings retention ratio (%): 8 zeros (Column length: 10)
#
# Company: IZMO Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 2 zeros (Column length: 20)
#       Current tax: 2 zeros (Column length: 20)
#       Deferred tax: 2 zeros (Column length: 20)
#       Total tax expenses: 1 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 42 zeros (Column length: 45)
#       Tax: 28 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Pbt/share (rs.): 1 zeros (Column length: 20)
#       Total debt/equity (x): 3 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 18 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 18 zeros (Column length: 20)
#       Earnings retention ratio (%): 9 zeros (Column length: 20)
#
# Company: Jeevan Scientific Technology Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 15 zeros (Column length: 15)
#       Net inc/dec in cash and cash equivalents: 3 zeros (Column length: 15)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 3 zeros (Column length: 15)
#       Finance costs: 1 zeros (Column length: 15)
#       Current tax: 9 zeros (Column length: 15)
#       Deferred tax: 6 zeros (Column length: 15)
#       Total tax expenses: 6 zeros (Column length: 15)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 3 zeros (Column length: 45)
#       Exceptional items: 43 zeros (Column length: 45)
#       Tax: 10 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Dividend payout ratio (np) (%): 13 zeros (Column length: 15)
#       Dividend payout ratio (cp) (%): 13 zeros (Column length: 15)
#       Earnings retention ratio (%): 9 zeros (Column length: 15)
#       Enterprise value (cr.): 5 zeros (Column length: 15)
#       Ev/ebitda (x): 5 zeros (Column length: 15)
#
# Company: Kati Patang Lifestyle Ltd
#
# ...
#       Foreign exchange gains / losses: 15 zeros (Column length: 15)
#       Net inc/dec in cash and cash equivalents: 3 zeros (Column length: 15)
#       Cash and cash equivalents begin of year: 2 zeros (Column length: 15)
#       Cash and cash equivalents end of year: 2 zeros (Column length: 15)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Other income: 14 zeros (Column length: 15)
#       Operating and direct expenses: 3 zeros (Column length: 15)
#       Employee benefit expenses: 3 zeros (Column length: 15)
#       Finance costs: 12 zeros (Column length: 15)
#       Depreciation and amortisation expenses: 1 zeros (Column length: 15)
#       Other expenses: 1 zeros (Column length: 15)
#       Profit/loss before exceptional, extraordinary items and tax: 4 zeros (Column length: 15)
#       Profit/loss before tax: 4 zeros (Column length: 15)
#       Current tax: 9 zeros (Column length: 15)
#       Deferred tax: 14 zeros (Column length: 15)
#       Total tax expenses: 8 zeros (Column length: 15)
#       Profit/loss after tax and before extraordinary items: 4 zeros (Column length: 15)
#       Profit/loss from continuing operations: 4 zeros (Column length: 15)
#       Profit/loss for the period: 4 zeros (Column length: 15)
#       Basic eps (rs.): 1 zeros (Column length: 15)
#       Diluted eps (rs.): 1 zeros (Column length: 15)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 8 zeros (Column length: 45)
#       Total income from operations: 8 zeros (Column length: 45)
#       Other expenses: 5 zeros (Column length: 45)
#       P/l before other inc. , int., excpt. items & tax: 2 zeros (Column length: 45)
#       Other income: 44 zeros (Column length: 45)
#       P/l before int., excpt. items & tax: 2 zeros (Column length: 45)
#       Interest: 24 zeros (Column length: 45)
#       P/l before exceptional items & tax: 2 zeros (Column length: 45)
#       Exceptional items: 45 zeros (Column length: 45)
#       P/l before tax: 2 zeros (Column length: 45)
#       Tax: 23 zeros (Column length: 45)
#       P/l after tax from ordinary activities: 3 zeros (Column length: 45)
#       Net profit/(loss) for the period: 3 zeros (Column length: 45)
#       Basic eps: 3 zeros (Column length: 45)
#       Diluted eps: 3 zeros (Column length: 45)
#       Basic eps.: 3 zeros (Column length: 45)
#       Diluted eps.: 3 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Pbit/share (rs.): 1 zeros (Column length: 15)
#       Pbt/share (rs.): 1 zeros (Column length: 15)
#       Net profit/share (rs.): 1 zeros (Column length: 15)
#       Pbit margin (%): 1 zeros (Column length: 15)
#       Pbt margin (%): 1 zeros (Column length: 15)
#       Net profit margin (%): 1 zeros (Column length: 15)
#       Total debt/equity (x): 12 zeros (Column length: 15)
#       Dividend payout ratio (np) (%): 15 zeros (Column length: 15)
#       Dividend payout ratio (cp) (%): 15 zeros (Column length: 15)
#       Earnings retention ratio (%): 13 zeros (Column length: 15)
#
# Company: Trigyn Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 6 zeros (Column length: 20)
#       Finance costs: 3 zeros (Column length: 20)
#       Current tax: 8 zeros (Column length: 20)
#       Deferred tax: 8 zeros (Column length: 20)
#       Total tax expenses: 3 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Other income: 1 zeros (Column length: 45)
#       Exceptional items: 15 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 13 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 19 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 19 zeros (Column length: 20)
#       Earnings retention ratio (%): 10 zeros (Column length: 20)
#
# Company: Unicommerce Esolutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used from financing activities: 4 zeros (Column length: 5)
#       Foreign exchange gains / losses: 5 zeros (Column length: 5)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Finance costs: 4 zeros (Column length: 5)
#       Current tax: 1 zeros (Column length: 5)
#       Deferred tax: 2 zeros (Column length: 5)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 5 zeros (Column length: 5)
#       Diluted eps: 1 zeros (Column length: 5)
#       Diluted eps.: 1 zeros (Column length: 5)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 5 zeros (Column length: 5)
#       Dividend payout ratio (np) (%): 5 zeros (Column length: 5)
#       Dividend payout ratio (cp) (%): 5 zeros (Column length: 5)
#       Earnings retention ratio (%): 5 zeros (Column length: 5)
#       Enterprise value (cr.): 5 zeros (Column length: 5)
#       Ev/ebitda (x): 5 zeros (Column length: 5)
#
# Company: USG Tech Solutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1 zeros (Column length: 20)
#       Net cashflow from operating activities: 1 zeros (Column length: 20)
#       Net cash used in investing activities: 2 zeros (Column length: 20)
#       Net cash used from financing activities: 3 zeros (Column length: 20)
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 3 zeros (Column length: 20)
#       Cash and cash equivalents begin of year: 3 zeros (Column length: 20)
#       Cash and cash equivalents end of year: 1 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Revenue from operations [gross]: 6 zeros (Column length: 20)
#       Revenue from operations [net]: 6 zeros (Column length: 20)
#       Total operating revenues: 6 zeros (Column length: 20)
#       Other income: 3 zeros (Column length: 20)
#       Total revenue: 3 zeros (Column length: 20)
#       Operating and direct expenses: 8 zeros (Column length: 20)
#       Employee benefit expenses: 1 zeros (Column length: 20)
#       Finance costs: 15 zeros (Column length: 20)
#       Current tax: 10 zeros (Column length: 20)
#       Deferred tax: 8 zeros (Column length: 20)
#       Total tax expenses: 7 zeros (Column length: 20)
#       Profit/loss after tax and before extraordinary items: 1 zeros (Column length: 20)
#       Profit/loss from continuing operations: 1 zeros (Column length: 20)
#       Profit/loss for the period: 1 zeros (Column length: 20)
#       Basic eps (rs.): 5 zeros (Column length: 20)
#       Diluted eps (rs.): 5 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 32 zeros (Column length: 45)
#       Total income from operations: 30 zeros (Column length: 45)
#       depreciat: 22 zeros (Column length: 45)
#       Other income: 27 zeros (Column length: 45)
#       P/l before int., excpt. items & tax: 1 zeros (Column length: 45)
#       Interest: 41 zeros (Column length: 45)
#       P/l before exceptional items & tax: 1 zeros (Column length: 45)
#       Exceptional items: 42 zeros (Column length: 45)
#       P/l before tax: 1 zeros (Column length: 45)
#       Tax: 38 zeros (Column length: 45)
#       P/l after tax from ordinary activities: 1 zeros (Column length: 45)
#       Net profit/(loss) for the period: 1 zeros (Column length: 45)
#       Basic eps: 16 zeros (Column length: 45)
#       Diluted eps: 20 zeros (Column length: 45)
#       Basic eps.: 16 zeros (Column length: 45)
#       Diluted eps.: 20 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Revenue from operations/share (rs.): 6 zeros (Column length: 20)
#       Pbdit/share (rs.): 1 zeros (Column length: 20)
#       Pbit/share (rs.): 2 zeros (Column length: 20)
#       Pbt/share (rs.): 2 zeros (Column length: 20)
#       Net profit/share (rs.): 3 zeros (Column length: 20)
#       Pbdit margin (%): 6 zeros (Column length: 20)
#       Pbit margin (%): 6 zeros (Column length: 20)
#       Pbt margin (%): 6 zeros (Column length: 20)
#       Net profit margin (%): 6 zeros (Column length: 20)
#       Return on networth / equity (%): 1 zeros (Column length: 20)
#       Return on assets (%): 1 zeros (Column length: 20)
#       Total debt/equity (x): 10 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 20 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 20 zeros (Column length: 20)
#       Earnings retention ratio (%): 11 zeros (Column length: 20)
#
# Company: VEDAVAAG Systems Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used in investing activities: 1 zeros (Column length: 19)
#       Net cash used from financing activities: 1 zeros (Column length: 19)
#       Foreign exchange gains / losses: 19 zeros (Column length: 19)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Other income: 2 zeros (Column length: 19)
#       Finance costs: 2 zeros (Column length: 19)
#       Deferred tax: 3 zeros (Column length: 19)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Employees cost: 11 zeros (Column length: 45)
#       depreciat: 1 zeros (Column length: 45)
#       Other income: 22 zeros (Column length: 45)
#       Interest: 18 zeros (Column length: 45)
#       Exceptional items: 45 zeros (Column length: 45)
#       Tax: 2 zeros (Column length: 45)
#       Basic eps: 3 zeros (Column length: 45)
#       Diluted eps: 3 zeros (Column length: 45)
#       Basic eps.: 3 zeros (Column length: 45)
#       Diluted eps.: 3 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 6 zeros (Column length: 19)
#       Dividend payout ratio (np) (%): 14 zeros (Column length: 19)
#       Dividend payout ratio (cp) (%): 14 zeros (Column length: 19)
#       Earnings retention ratio (%): 4 zeros (Column length: 19)
#       Enterprise value (cr.): 3 zeros (Column length: 19)
#       Ev/ebitda (x): 3 zeros (Column length: 19)
#
# Company: WEP Solutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cashflow from operating activities: 1 zeros (Column length: 20)
#       Net cash used in investing activities: 1 zeros (Column length: 20)
#       Net cash used from financing activities: 1 zeros (Column length: 20)
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 1 zeros (Column length: 20)
#       Cash and cash equivalents begin of year: 2 zeros (Column length: 20)
#       Cash and cash equivalents end of year: 3 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Other income: 1 zeros (Column length: 20)
#       Operating and direct expenses: 14 zeros (Column length: 20)
#       Finance costs: 4 zeros (Column length: 20)
#       Current tax: 8 zeros (Column length: 20)
#       Deferred tax: 6 zeros (Column length: 20)
#       Total tax expenses: 7 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       P/l before other inc. , int., excpt. items & tax: 1 zeros (Column length: 45)
#       Exceptional items: 45 zeros (Column length: 45)
#       Tax: 1 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 1 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 16 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 16 zeros (Column length: 20)
#       Earnings retention ratio (%): 12 zeros (Column length: 20)
#
# Company: Wipro Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Foreign exchange gains / losses: 6 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 8 zeros (Column length: 20)
#       Deferred tax: 3 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 45 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
# Company: Xchanging Solutions Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1 zeros (Column length: 20)
#       Net cashflow from operating activities: 1 zeros (Column length: 20)
#       Net cash used in investing activities: 1 zeros (Column length: 20)
#       Net cash used from financing activities: 1 zeros (Column length: 20)
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 1 zeros (Column length: 20)
#       Cash and cash equivalents begin of year: 1 zeros (Column length: 20)
#       Cash and cash equivalents end of year: 1 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 14 zeros (Column length: 20)
#       Current tax: 1 zeros (Column length: 20)
#       Deferred tax: 5 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       P/l before other inc. , int., excpt. items & tax: 1 zeros (Column length: 45)
#       Interest: 4 zeros (Column length: 45)
#       Exceptional items: 40 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 10 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 19 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 19 zeros (Column length: 20)
#       Earnings retention ratio (%): 12 zeros (Column length: 20)
#
# Company: Xtglobal Infotech Ltd
#
#   Sheet Name: Balance_Sheet
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net profit/loss before extraordinary items and tax: 1 zeros (Column length: 20)
#       Net cashflow from operating activities: 1 zeros (Column length: 20)
#       Net cash used in investing activities: 7 zeros (Column length: 20)
#       Net cash used from financing activities: 10 zeros (Column length: 20)
#       Foreign exchange gains / losses: 20 zeros (Column length: 20)
#       Net inc/dec in cash and cash equivalents: 2 zeros (Column length: 20)
#       Cash and cash equivalents begin of year: 2 zeros (Column length: 20)
#       Cash and cash equivalents end of year: 2 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Other income: 6 zeros (Column length: 20)
#       Operating and direct expenses: 15 zeros (Column length: 20)
#       Finance costs: 8 zeros (Column length: 20)
#       Depreciation and amortisation expenses: 1 zeros (Column length: 20)
#       Current tax: 18 zeros (Column length: 20)
#       Deferred tax: 15 zeros (Column length: 20)
#       Total tax expenses: 15 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Net sales/income from operations: 4 zeros (Column length: 45)
#       Total income from operations: 4 zeros (Column length: 45)
#       Employees cost: 1 zeros (Column length: 45)
#       depreciat: 14 zeros (Column length: 45)
#       Other income: 23 zeros (Column length: 45)
#       Interest: 24 zeros (Column length: 45)
#       Exceptional items: 39 zeros (Column length: 45)
#       Tax: 26 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Return on networth / equity (%): 7 zeros (Column length: 20)
#       Total debt/equity (x): 2 zeros (Column length: 20)
#       Dividend payout ratio (np) (%): 20 zeros (Column length: 20)
#       Dividend payout ratio (cp) (%): 20 zeros (Column length: 20)
#       Earnings retention ratio (%): 20 zeros (Column length: 20)
#
# Company: Zensar Technologies Ltd
#
#   Sheet Name: Balance_Sheet
#
#     Zero Values:
#       Other current liabilities: 3 zeros (Column length: 20)
#
#   Sheet Name: Cash_Flow
#
#     Zero Values:
#       Net cash used in investing activities: 1 zeros (Column length: 20)
#       Foreign exchange gains / losses: 15 zeros (Column length: 20)
#
#   Sheet Name: Profit_Loss
#
#     Zero Values:
#       Operating and direct expenses: 6 zeros (Column length: 20)
#       Finance costs: 1 zeros (Column length: 20)
#       Current tax: 1 zeros (Column length: 20)
#       Deferred tax: 5 zeros (Column length: 20)
#
#   Sheet Name: Quarterly
#
#     Zero Values:
#       Exceptional items: 45 zeros (Column length: 45)
#
#   Sheet Name: Ratio
#
#     Zero Values:
#       Total debt/equity (x): 13 zeros (Column length: 20)

# %%
import os
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import Font

# Define the base directory containing all company folders
input_file = r"C:\Users\rayya\OneDrive\Desktop\Programs\Financial-Management-Dataset-\Financial_Data\MoneyControl\Companies\IT Services & Consulting"
companies_list = os.listdir(input_file)

# Define output file
output_excel = os.path.join(input_file, "Zero_Values_Report.xlsx")

# Create a new Excel writer object
with pd.ExcelWriter(output_excel, engine='openpyxl') as writer:

    # Iterate over each company folder
    for company in companies_list:
        file_path = os.path.join(input_file, company, "Pruned_Excel", "Final_Parameters", "Semi_Final")

        # Define file name
        excel_file = os.path.join(file_path, f"{company}_Semi_Final.xlsx")

        # Check if the file exists before processing
        if os.path.exists(excel_file):
            data = []  # List to store zero value data

            # Load all sheets from the Excel file
            dfs = pd.read_excel(excel_file, sheet_name=None)

            # Iterate through each sheet in the Excel file
            for sheet_name, df in dfs.items():
                # Convert non-numeric columns to NaN (avoid counting 0s in text)
                df_numeric = df.apply(pd.to_numeric, errors='coerce')

                # Count occurrences of zero values per column
                zero_counts = (df_numeric == 0).sum()
                zero_columns = zero_counts[zero_counts > 0]  # Only columns with 0s

                # Collect data for zero values
                if not zero_columns.empty:
                    for column, count in zero_columns.items():
                        total_length = df_numeric[column].count() + df_numeric[column].isnull().sum()
                        data.append([sheet_name, column, count, total_length])

            # Create a DataFrame from collected data
            if data:
                df_result = pd.DataFrame(data, columns=["Sheet Name", "Column Name", "Zero Values", "Column Length"])

                # Save to the company sheet in the output file
                df_result.to_excel(writer, sheet_name=company, index=False)

    # Save the file
    writer.close()

# Apply formatting to the "Sheet Name" column
wb = load_workbook(output_excel)

for sheet in wb.sheetnames:
    ws = wb[sheet]

    # Apply bold formatting to "Sheet Name" column
    for row in ws.iter_rows(min_row=2, max_row=ws.max_row, min_col=1, max_col=1):
        for cell in row:
            cell.font = Font(bold=True)

# Save the formatted file
wb.save(output_excel)

print(f"\n Zero values report saved at: {output_excel}")
print("\n Formatting applied: Sheet names in bold")
# Out:
# c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 14
#      11 output_excel = os.path.join(input_file, "Zero_Values_Report.xlsx")
#      13 # Create a new Excel writer object
# ---> 14 with pd.ExcelWriter(output_excel, engine='openpyxl') as writer:
#      15
#      16     # Iterate over each company folder
#      17     for company in companies_list:
#      18         file_path = os.path.join(input_file, company, "Pruned_Excel", "Final_Parameters", "Semi_Final")
#
# File c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:1353, in ExcelWriter.__exit__(self, exc_type, exc_value, traceback)
#    1347 def __exit__(
#    1348     self,
#    1349     exc_type: type[BaseException] | None,
#    1350     exc_value: BaseException | None,
#    1351     traceback: TracebackType | None,
#    1352 ) -> None:
# -> 1353     self.close()
#
# File c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:1357, in ExcelWriter.close(self)
#    1355 def close(self) -> None:
#    1356     """synonym for save, to make it more file-like"""
# -> 1357     self._save()
#    1358     self._handles.close()
#
# File c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_openpyxl.py:110, in OpenpyxlWriter._save(self)
#     106 def _save(self) -> None:
#     107     """
#     108     Save workbook to disk.
#     109     """
# --> 110     self.book.save(self._handles.handle)
#     111     if "r+" in self._mode and not isinstance(self._handles.handle, mmap.mmap):
#     112         # truncate file to the written content
#     113         self._handles.handle.truncate()
#
# File c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\workbook\workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\writer\excel.py:291, in save_workbook(workbook, filename)
#     279 def save_workbook(workbook, filename):
#     280     """Save the given workbook on the filesystem under the name filename.
#     281
#     282     :param workbook: the workbook to save
#    (...)
#     289
#     290     """
# --> 291     archive = ZipFile(filename, 'w', ZIP_DEFLATED, allowZip64=True)
#     292     workbook.properties.modified = datetime.datetime.now(tz=datetime.timezone.utc).replace(tzinfo=None)
#     293     writer = ExcelWriter(workbook, archive)
#
# File c:\Users\rayya\AppData\Local\Programs\Python\Python313\Lib\zipfile\__init__.py:1386, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1384 self._didModify = True
#    1385 try:
# -> 1386     self.start_dir = self.fp.tell()
#    1387 except (AttributeError, OSError):
#    1388     self.fp = _Tellable(self.fp)
#
# ValueError: I/O operation on closed file
